# %% [markdown]
# # First Steps in Data Wrangling with Python

# %% [markdown]
# In this lab session, we will discuss the basics of
#   * Basis steps in Jupyter
#   * A (really) quick introduction into data wrangling with Python
#   * Getting data into Python
#   * Handling data in Python
#   * Transferring data to Tableau

# %% [markdown]
# ## Basic steps in Jupyter

# %% [markdown]
# ### Some principles:
#   * Everything is handled in cells. Cells contain source code, explanation, documentation, and output.
#   * Jupyter is interactive and differentiates between a command mode (`Esc`) and an edit mode (`Enter`).
#   * Keyboard shortcuts are vital to know for effective work in Jupyter

# %% [markdown]
# ### Most important keyboard shortcuts
#   * `Enter` will bring you into edit mode
#     + In edit mode you can write Python or [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#   * `Esc` will bring you in command mode
#     + `b` will create a new cell below the current sell (`a` creates a cell above)
#     + `y` interprets a cell as code
#     + `m` interprets a cell as markdown
#     + pressing `d` twice deletes a cell
#   * `Shift + Enter` runs a cell
#   * `Shift + Command + P` opens the command palette
#   * You can run shell commands using `!` - This is helpful to see available files

# %%
print ("This is a code cell that will be executed")
# Out:
# This is a code cell that will be executed

# %% [markdown]
# print ("This is a markdown cell that will be rendered")

# %% [markdown]
# ## A (really) quick introduction into data wrangling with Python

# %% [markdown]
# We use the pandas library to wrangle data. You can access the pandas documentation in the `Help` menu.

# %% [markdown]
# As a first step, lets go back to the dataset from the previous week (you may need to adapt this to your operating system):

# %%
# !ls ../Lab\ Session\ 1/*.csv
# Out:
# ../Lab Session 1/file1.csv ../Lab Session 1/file3.csv
# ../Lab Session 1/file2.csv ../Lab Session 1/final.csv

# %% [markdown]
# Let's have a look at the Jupyter notebook from last class [here](../Lab Session 1/Lab Session 1.ipynb).

# %% [markdown]
# ## Getting data into Python

# %% [markdown]
# Load pandas to handle data frames.

# %%
import pandas as pd

# %% [markdown]
# Have a look at the available csv files.

# %%
! ls *.csv
# Out:
# 2016_US_County_Level_Presidential_Results.csv
# ACS_15_5YR_S1901.csv
# ACS_15_5YR_S1901_metadata.csv

# %% [markdown]
# The following command allows us to display multiple outputs at the same time (Highly useful!) \[Reference: [dataquest.io](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)\]

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Load the election results and have a look at the table.

# %%
results = pd.read_csv('2016_US_County_Level_Presidential_Results.csv')
results.head()
results.tail()
# Out:
#    Unnamed: 0  votes_dem  votes_gop  total_votes   per_dem  per_gop    diff  \
# 0           0    93003.0   130413.0     246588.0  0.377159  0.52887  37,410
# 1           1    93003.0   130413.0     246588.0  0.377159  0.52887  37,410
# 2           2    93003.0   130413.0     246588.0  0.377159  0.52887  37,410
# 3           3    93003.0   130413.0     246588.0  0.377159  0.52887  37,410
# 4           4    93003.0   130413.0     246588.0  0.377159  0.52887  37,410
#
#   per_point_diff state_abbr county_name  combined_fips
# 0         15.17%         AK      Alaska           2013
# 1         15.17%         AK      Alaska           2016
# 2         15.17%         AK      Alaska           2020
# 3         15.17%         AK      Alaska           2050
# 4         15.17%         AK      Alaska           2060
#       Unnamed: 0  votes_dem  votes_gop  total_votes   per_dem   per_gop  \
# 3136        3136     3233.0    12153.0      16661.0  0.194046  0.729428
# 3137        3137     7313.0     3920.0      12176.0  0.600608  0.321945
# 3138        3138     1202.0     6154.0       8053.0  0.149261  0.764187
# 3139        3139      532.0     2911.0       3715.0  0.143203  0.783580
# 3140        3140      294.0     2898.0       3334.0  0.088182  0.869226
#
#        diff per_point_diff state_abbr        county_name  combined_fips
# 3136  8,920         53.54%         WY  Sweetwater County          56037
# 3137  3,393         27.87%         WY       Teton County          56039
# 3138  4,952         61.49%         WY       Uinta County          56041
# 3139  2,379         64.04%         WY    Washakie County          56043
# 3140  2,604         78.10%         WY      Weston County          56045

# %% [markdown]
# ## Handling data in Python

# %% [markdown]
# Perform some basic quality checks.

# %% [markdown]
# How many counties are in the dataset? Does that match your expectations?

# %%
len(results)
# Out:
# 3141

# %% [markdown]
# What is the unique id for each row?

# %%
names = results.county_name.value_counts()
names[names > 1]
# Out:
# Washington County      30
# Alaska                 29
# Jefferson County       25
# Franklin County        24
# Lincoln County         23
# Jackson County         23
# Madison County         19
# Clay County            18
# Montgomery County      18
# Union County           17
# Monroe County          17
# Marion County          17
# Wayne County           16
# Grant County           14
# Greene County          14
# Warren County          14
# Carroll County         13
# Marshall County        12
# Lee County             12
# Adams County           12
# Lake County            12
# Polk County            12
# Clark County           12
# Johnson County         12
# Douglas County         12
# Calhoun County         11
# Crawford County        11
# Scott County           11
# Fayette County         11
# Morgan County          11
#                        ..
# Coos County             2
# Harding County          2
# Halifax County          2
# Crittenden County       2
# Brunswick County        2
# Elbert County           2
# Johnston County         2
# Barry County            2
# Stanton County          2
# Pottawatomie County     2
# Bryan County            2
# Ashland County          2
# Owen County             2
# Barton County           2
# Sierra County           2
# Mecklenburg County      2
# Laurens County          2
# Curry County            2
# Kendall County          2
# Albany County           2
# Suffolk County          2
# Highland County         2
# Cleburne County         2
# Dade County             2
# Menominee County        2
# Talbot County           2
# Craig County            2
# Berrien County          2
# Atchison County         2
# Wilkinson County        2
# Name: county_name, dtype: int64

# %%
names = results.combined_fips.value_counts()
names[names > 1]
# Out:
# Series([], Name: combined_fips, dtype: int64)

# %% [markdown]
# We want the election results per county. What is the appropriate field? Are there problems with the field?

# %%
results['diff'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     751         try:
# --> 752             x = float(x)
#     753         except Exception:
#
# ValueError: could not convert string to float: '37,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41012,20254,3715834,85920,6582,3911,17519,6062,0407,28512,1599931,3973,9965,05411,6319,4223441,59610,8432,84829,0049,3907,04218,09719,1835,58421,7825,3477,2698,4453,1681,6003,33720,02012,98020,9674,78417,8587,12113,33419,4843,1315,84326,7643839,84124,30422,6581,46124,74126,1762,4201,4822,6425,40736749,91926,0293,1588,4887,69615,95519,7223,6652,5928,3541,8862,93010,49232,8579,3008469183,4396347921,7807,3531,7372,3162,18912,32412,1791,4152,5823423121,60314,6453,6582,40313,7703,7537,6422,0205,0161,8057,0472,9311,6796,4903,6517222,8015061,2032,2074,02514,2643,3303,7007,0201,3671021,8388452,1761,0271,9441,8492,4661,2715,39610,8761,69128,1

#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    5630                                       skipna=skipna)
#    5631         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 5632                             numeric_only=numeric_only)
#    5633
#    5634     return set_function_name(stat_func, name, cls)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2318                                           'numeric_only.'.format(name))
#    2319             with np.errstate(all='ignore'):
# -> 2320                 return op(delegate, skipna=skipna, **kwds)
#    2321
#    2322         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      48             try:
#      49                 with np.errstate(invalid='ignore'):
# ---> 50                     return f(*args, **kwargs)
#      51             except ValueError as e:
#      52                 # we want to transform an object array
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     107             except Exception:
#     108                 try:
# --> 109                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     110                 except ValueError as e:
#     111                     # we want to transform an object array
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     297         dtype_count = dtype
#     298     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 299     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     300
#     301     if axis is not None and getattr(the_sum, 'ndim', False):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     755                 x = complex(x)
#     756             except Exception:
# --> 757                 raise TypeError('Could not convert %s to numeric' % str(x))
#     758     return x
#     759
#
# TypeError: Could not convert 37,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41037,41012,20254,3715834,85920,6582,3911,17519,6062,0407,28512,1599931,3973,9965,05411,6319,4223441,59610,8432,84829,0049,3907,04218,09719,1835,58421,7825,3477,2698,4453,1681,6003,33720,02012,98020,9674,78417,8587,12113,33419,4843,1315,84326,7643839,84124,30422,6581,46124,74126,1762,4201,4822,6425,40736749,91926,0293,1588,4887,69615,95519,7223,6652,5928,3541,8862,93010,49232,8579,3008469183,4396347921,7807,3531,7372,3162,18912,32412,1791,4152,5823423121,60314,6453,6582,40313,7703,7537,6422,0205,0161,8057,0472,9311,6796,4903,6517222,8015061,2032,2074,02514,2643,3303,7007,0201,3671021,8388452,1761,0271,9441,8492,4661,2715,39610,8761,69128,1953,08322,6051,8712,35416,5852,2063,9338362,8924,5343,8358,12215,8812273,1286,8819,7458,7356,9264,7248002,06341,42538,1712,80348,63018,1207,03429,1572,250395,1621074,3353,5175,334892180,8391,64912,3909,7112,7238,71317,1721,09332,6834,5444885,3501,273,4855,93869,1192,0633,3343,3701,61561638,35514,2151,51383,87517,0081,85529,631110,7443,57958,555180,436277,95021,47510,329165,84946,380346,02065,02727,1164474,10647,56478,6069794,9498,41053311,3894,90651,72521,2825,07912,66413738,7271,7451,43858585,9495,2585107781591325287331,2627,536130,97470933,1334,4998,48070,6999,7911,866701,1481,81814224445721,6526352,3683362,8299,5461,0421,4745,42927,1711074,4193,8518,8654,9761,2693532,7021,3554,7172,3351992,3491,0752,338236501,9307484,4386,0331,99530,0133,05483,26685,87713,5406,45945,2288,3774,4613,962248,6703,64277,39823,27828,7868,18240,3215,98962,095288,4353,41126,77531,61247,13044,35612,7602,9834,5526,43431,25611,8192,3818,2735,2831,7253,6051,5403,0911,58227,21114,60840,4946,62419,5677,8483932,28039,29166,41638,1598,6671,8911,32330,61545,75223,024289,3402,93623,37248,0775,389134,48835,035100,64951,9455,41940,03411,95346,72826,4223,65445,5963,43630,09110,3264,7743,55333,9706,15918,8346,3694,0581,1772,7491252745,44614,52521,6751,6364,36711,7942,6234,9421,1756,5035,6642394,1513496,3731,63817,56116,0911,94615,3491534,84555,40816,82313164,1681,0396,8145,4856,43224,1972,42325,9412,2131,7044,0828,4361,905191,6003,1858112,9976
results['W'] = results.per_dem - results.per_gop
results.head()
# Out:
#    Unnamed: 0  votes_dem  votes_gop  total_votes   per_dem  per_gop     diff  \
# 0           0    93003.0   130413.0     246588.0  0.377159  0.52887  37410.0
# 1           1    93003.0   130413.0     246588.0  0.377159  0.52887  37410.0
# 2           2    93003.0   130413.0     246588.0  0.377159  0.52887  37410.0
# 3           3    93003.0   130413.0     246588.0  0.377159  0.52887  37410.0
# 4           4    93003.0   130413.0     246588.0  0.377159  0.52887  37410.0
#
#   per_point_diff state_abbr county_name  combined_fips         W
# 0         15.17%         AK      Alaska           2013 -0.151711
# 1         15.17%         AK      Alaska           2016 -0.151711
# 2         15.17%         AK      Alaska           2020 -0.151711
# 3         15.17%         AK      Alaska           2050 -0.151711
# 4         15.17%         AK      Alaska           2060 -0.151711

# %% [markdown]
# Make a new dataframe that only contains the relevant columns.

# %%
clean_results = results[['combined_fips','W']]
clean_results.head()
# Out:
#    combined_fips         W
# 0           2013 -0.151711
# 1           2016 -0.151711
# 2           2020 -0.151711
# 3           2050 -0.151711
# 4           2060 -0.151711

# %% [markdown]
# Load the census data.

# %%
income = pd.read_csv('ACS_15_5YR_S1901.csv', encoding = "latin1")
income.head()
income.tail()
len(income)
# Out:
#            GEO.id  GEO.id2        GEO.display-label  HC01_EST_VC01  \
# 0  0500000US01001     1001  Autauga County, Alabama          20396
# 1  0500000US01003     1003  Baldwin County, Alabama          74104
# 2  0500000US01005     1005  Barbour County, Alabama           9222
# 3  0500000US01007     1007     Bibb County, Alabama           7027
# 4  0500000US01009     1009   Blount County, Alabama          20816
#
#    HC01_MOE_VC01  HC02_EST_VC01  HC02_MOE_VC01  HC03_EST_VC01  HC03_MOE_VC01  \
# 0            413          14213            539          11436            534
# 1           1265          50276           1220          39968           1191
# 2            272           6059            259           3991            223
# 3            354           5296            359           4029            329
# 4            427          15639            416          12373            470
#
#    HC04_EST_VC01      ...        HC04_EST_VC19  HC04_MOE_VC19  HC01_EST_VC20  \
# 0           6183      ...                  NaN            NaN            NaN
# 1          23828      ...                  NaN            NaN            NaN
# 2           3163      ...                  NaN            NaN            NaN
# 3           1731      ...                  NaN            NaN            NaN
# 4           5177      ...                  NaN            NaN            NaN
#
#    HC01_MOE_VC20  HC02_EST_VC20  HC02_MOE_VC20  HC03_EST_VC20  HC03_MOE_VC20  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    HC04_EST_VC20  HC04_MOE_VC20
# 0           26.4            NaN
# 1           26.6            NaN
# 2           25.6            NaN
# 3           33.4            NaN
# 4           24.5            NaN
#
# [5 rows x 131 columns]
#               GEO.id  GEO.id2           GEO.display-label  HC01_EST_VC01  \
# 3137  0500000US56037    56037  Sweetwater County, Wyoming          16679
# 3138  0500000US56039    56039       Teton County, Wyoming           8187
# 3139  0500000US56041    56041       Uinta County, Wyoming           7502
# 3140  0500000US56043    56043    Washakie County, Wyoming           3512
# 3141  0500000US56045    56045      Weston County, Wyoming           2986
#
#       HC01_MOE_VC01  HC02_EST_VC01  HC02_MOE_VC01  HC03_EST_VC01  \
# 3137            308          11412            391           9071
# 3138            412           4840            414           4141
# 3139            251           5345            288           4310
# 3140            121           2233            147           1816
# 3141            136           1886            178           1563
#
#       HC03_MOE_VC01  HC04_EST_VC01      ...        HC04_EST_VC19  \
# 3137            435           5267      ...                  NaN
# 3138            374           3347      ...                  NaN
# 3139            332           2157      ...                  NaN
# 3140            148           1279      ...                  NaN
# 3141            171           1100      ...                  NaN
#
#       HC04_MOE_VC19  HC01_EST_VC20  HC01_MOE_VC20  HC02_EST_VC20  \
# 3137            NaN            NaN            NaN            NaN
# 3138            NaN            NaN            NaN            NaN
# 3139            NaN            NaN            NaN            NaN
# 3140            NaN            NaN            NaN            NaN
# 3141            NaN            NaN            NaN            NaN
#
#       HC02_MOE_VC20  HC03_EST_VC20  HC03_MOE_VC20  HC04_EST_VC20  \
# 3137            NaN            NaN            NaN           18.8
# 3138            NaN            NaN            NaN           41.0
# 3139            NaN            NaN            NaN           24.0
# 3140            NaN            NaN            NaN           31.4
# 3141            NaN            NaN            NaN           19.0
#
#       HC04_MOE_VC20
# 3137            NaN
# 3138            NaN
# 3139            NaN
# 3140            NaN
# 3141            NaN
#
# [5 rows x 131 columns]
# 3142

# %% [markdown]
# Identify the column that contains the mean income.

# %%
income['HC01_EST_VC15'].mean()
# Out:
# 61215.25461489497

# %% [markdown]
# Make a new dataframe that only contains the relevant columns.

# %%
clean_income = income[['GEO.id2','GEO.display-label','HC01_EST_VC15']]
clean_income.head()
# Out:
#    GEO.id2        GEO.display-label  HC01_EST_VC15
# 0     1001  Autauga County, Alabama          64765
# 1     1003  Baldwin County, Alabama          68169
# 2     1005  Barbour County, Alabama          44688
# 3     1007     Bibb County, Alabama          52241
# 4     1009   Blount County, Alabama          54884

# %% [markdown]
# Join the two datasets.

# %%
cons = pd.merge(clean_results, clean_income, left_on="combined_fips", right_on="GEO.id2")
cons.head()
cons.tail()
# Out:
#    combined_fips         W  GEO.id2                   GEO.display-label  \
# 0           2013 -0.151711     2013      Aleutians East Borough, Alaska
# 1           2016 -0.151711     2016  Aleutians West Census Area, Alaska
# 2           2020 -0.151711     2020      Anchorage Municipality, Alaska
# 3           2050 -0.151711     2050          Bethel Census Area, Alaska
# 4           2060 -0.151711     2060         Bristol Bay Borough, Alaska
#
#    HC01_EST_VC15
# 0          71231
# 1          94923
# 2          99630
# 3          65709
# 4          87875
#       combined_fips         W  GEO.id2           GEO.display-label  \
# 3134          56037 -0.535382    56037  Sweetwater County, Wyoming
# 3135          56039  0.278663    56039       Teton County, Wyoming
# 3136          56041 -0.614926    56041       Uinta County, Wyoming
# 3137          56043 -0.640377    56043    Washakie County, Wyoming
# 3138          56045 -0.781044    56045      Weston County, Wyoming
#
#       HC01_EST_VC15
# 3134          79150
# 3135         110861
# 3136          70306
# 3137          63530
# 3138          69975

# %% [markdown]
# Perform some quality checks on your result.

# %%
len(cons)
# Out:
# 3139

# %% [markdown]
# ## Transferring data to Tableau

# %% [markdown]
# Write the data to a file for Tableau.

# %%
cons.to_csv('final.csv', sep=';')
