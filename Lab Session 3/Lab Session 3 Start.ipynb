# %% [markdown]
# # First Steps in Data Scraping with BeautifulSoup

# %% [markdown]
# In this lab session, we will discuss how to get data from websites with BeautifulSoup.
#
#   * You will find BeautifulSoup [here](https://www.crummy.com/software/BeautifulSoup/).
#   * The documentation for BeautifulSoup is [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %% [markdown]
# ## Installation

# %% [markdown]
# Install BeautifulSoup using your package manager, e.g., `pip install beautifulsoup4`

# %% [markdown]
# ## School rankings

# %% [markdown]
# School rankings are typically published on websites with little or no download available.
#
# We will scrap three webpages, which are already downloaded and in the working directory of this notebook.

# %% [markdown]
# Let's have a look at the files (please adapt to your operation system)

# %%
# !ls *.html
# Out:
# payscale.html ruw.html      scu.html

# %% [markdown]
# ## Preparation

# %% [markdown]
# We need to load a set of libraries.
#   * Pandas for handling dataframes
#   * BeautifulSoup to scrap webpages
#   * `urllib` to handle URLs
#   * `json` to handle JSON-Files
#   * `re` to handle regular expressions

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib as url
import json
import re

# %% [markdown]
# ## Scraping of ROI numbers from PayScale

# %% [markdown]
# We open the downloaded webpage that contains the ROI information

# %%
soup = bs(open('payscale.html'), 'lxml')

# %% [markdown]
# Let's have a look at the 'soup' that we just created.

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head id="ctl00_m_htmlHeader"><title>
# 	PayScale College ROI Report: Best Value Colleges
# </title><meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <link href="//cdn-payscale.com" rel="dns-prefetch"/>
# <link href="//cdn-payscale.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <meta content="" property="fb:app_id"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://cdn-payscale.com/images/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn-payscale.com/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://cdn-payscale.com/images/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://cdn-payscale.com/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://cdn-payscale.com/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <style>
# </style>
# <meta content="Use PayScale's College ROI Report to determine which colleges offer the best value. Learn which schools offer the highest return on investment for tuition." name="description"/><link href="https://cdn-payscale.com/resources/2017.0412.2333.205/css/frozen/consumer/header-footer.min.css" rel="stylesheet" type="text/css"/><link href="https://fonts.googleapis.com/css?family=Open+Sans:400,400i,600,700,700i" rel="stylesheet" type="text/css"/><link href="https://cdn-payscale.com/resources/2017.0412.2333.205/css/frozen/consumer/payscale-consumer.min.css" rel="stylesheet" type="text/css"/><link href="https://cdn-payscale.com/resources/2017.0412.2333.205/css/dist/consumer/react/college-roi-bundle.min.css" rel="stylesheet" type="text/css"/><link href="https://cdn-payscale.com/resources/2017.0412.2333.205/css/consumer/ilwidget.css" rel="stylesheet" type="text/css"/><script>
# var dataLayer = [{"cacheControl":"public","origin":"payscale"}];
# </script>
# <meta content="article" property="og:type"/>
# <meta content="PayScale" property="og:site_name"/><link href="/college-roi?page=119" rel="prev"/><link href="/college-roi?page=121" rel="next"/><link href="http://www.payscale.com/college-roi?page=120" rel="canonical"/><meta content="PayScale College ROI Report: Best Value Colleges" property="og:title"/><meta content="http://www.payscale.com/college-roi" property="og:url"/><meta content="Use PayScale's College ROI Report to determine which colleges offer the best value. Learn which schools offer the highest return on investment for tuition." property="og:description"/><meta content="https://www.payscale.com/content/roi/2017/roi-fb.png" property="og:image"/><link href="/opensearch.xml" rel="search" title="PayScale Salary Search" type="application/opensearchdescription+xml"/><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/lib/loadcss/1.2.1/loadCSS.js"></script><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/lib/loadcss/1.2.1/cssrelpreload.js"></script><script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/frozen/consumer/header-footer.min.js"></script><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/lib/typeahead/0.10.5/typeahead.bundle.js"></script><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/frozen/consumer/payscale-consumer.min.js"></script><script defer="" src="https://cdn-payscale.com/resources/2017.0412.2333.205/js/dist/consumer/react/college-roi-bundle.min.js"></script><script defer="" src="//platform.linkedin.com/in.js"></script><script defer="" src="//apis.google.com/js/plusone.js"></script><script defer="" src="//platform.twitter.com/widgets.js"></script><script async="" src="//assets.pinterest.com/js/pinit.js"></script></head>
# <body>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P3CVWR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>    (function (w, d, s, l, i) {
# w[l] = w[l] || []; w[l].push({ 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
# }); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-P3CVWR');</script>
# <!-- End Google Tag Manager -->
# <span class="dynamicContentBegin hidden" data-content="PayscaleMasterBodyContent"></span><span class="dynamicContentBegin hidden" data-content="ConsumerBrowserSunsetWarning"></span><span class="dynamicContentEnd hidden" data-content="ConsumerBrowserSunsetWarning"></span><span class="dynamicContentEnd hidden" data-content="PayscaleMasterBodyContent"></span>
# <span class="dynamicContentBegin hidden" data-content="/header-footer/header_insight_bar"></span>
# <style>
#   .dashboardButton {
#     background-color: #a5d649;
#     border: 1px solid #9bcf3e;
#     border-radius: 3px;
#     color: #fff;
#     cursor: pointer;
#     font-family: "Open Sans","Helvetica Neue",Helvetica,Arial,sans-serif;
#     font-size: 13px;
#     line-height: 18px;
#     margin: 0;
#     padding: 6px 12px;
#   }
#
#   .dashboardButton:hover {
#     background-color: #8fc330;
#     border-color: #7aa629;
#   }
#
#   .insightBarRowWrap {
#     max-width: 1000px;
#     margin: 0 auto;
#   }
#
#   .insightBarColWrap {
#     margin: 0 15px;
#     padding: 7px 0 8px;
#     text-align: right;
#   }
#
#   .insightBarCopyWrap {
#     color: #fff;
#     display: inline-block;
#     font-size: 18px;
#     position: relative;
#     top: 2px;
#   }
# </style>
# <div class="container-fluid hidden-xs insight-bar hidden" style="background-color: #2d2d2e;">
# <div class="insightBarRowWrap">
# <div class="insightBarColWrap">
# <div class="insightBarCopyWrap">
#         Welcome back! Go to your
#       </div> <a href="http://insight.payscale.com/" style="margin-left: 3px;" target="">
# <input class="dashboardButton" type="button" value="Dashboard"/>
# </a>
# </div>
# </div>
# </div><span class="dynamicContentEnd hidden" data-content="/header-footer/header_insight_bar"></span>
# <span id="pageTop"></span>
# <div id="_header">
# <span class="dynamicContentBegin hidden" data-content="/header-footer/header"></span><div id="psHeaderCon">
# <div class="menuStart" id="psHeader">
# <a class="ps-logo-svg" href="/"><img alt="" src="https://cdn-payscale.com/images/header/payscale_logo_tagline_490x163.svg"/></a>
# <div class="menuToggle rightSideNav psMobile">
# <img alt="menu" class="hamburger" height="18" src="https://cdn-payscale.com/images/header/hamburger.png" width="19"/>
# <img alt="close menu" class="xburger" height="16" src="https://cdn-payscale.com/images/header/x-black-16x16.png" width="16"/>
# </div>
# <ul class="psHeaderMenu">
# <li class="menuTop" id="personal">
# <a class="menuLink" href="/mypayscale.aspx">
# <span class="menuItem" id="psHeaderPersonal">
#             PERSONAL
#             <span class="menuItemBlurb">What am I worth?</span>
# </span>
# </a>
# <div class="flyout">
# <div class="flyoutBody">
# <div class="menuColumn whatsYourWorthAd" id="menuAdLeft">
# <h3 class="whatsYourWorthHeadline">What are you worth?</h3>
# <div class="whatsYourWorthText">
#                 Find out what you
#                 <br/>
#                 should be paid.
#               </div>
# <a href="/startwizard.aspx?starttype=Header">
# <span class="primaryButton">
#                   Get a Free <br/>Salary Report
#                 </span>
# </a>
# </div>
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/mypayscale.aspx">Salary Reports</a>
# </div>
# <div class="navItem">
# <a href="/mypayscale.aspx">Your Salary</a>
# </div>
# <div class="navItem">
# <a href="/startwizard.aspx?startType=Header">Start New Survey</a>
# </div>
# <div class="navCategory">
# <a href="/research/US/Country=United_States/Salary">Career Research</a>
# </div>
# <div class="navItem">
# <a href="/research/US/Country=United_States/Salary">Employer &amp; Job Salaries</a>
# </div>
# <div class="navItem">
# <a href="/gigzig.aspx">Career Path Explorer</a>
# </div>
# <div class="navItem">
# <a href="/cost-of-living-calculator">Cost of Living Calculator</a>
# </div>
# <div class="navItem">
# <a href="/career-goals">Career Goal Tracker</a>
# </div>
# <div class="navCategory">
# <a href="/career-news">Career News Blog</a>
# </div>
# </div>
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/resources.aspx">Special Reports</a>
# </div>
# <div class="navItem">
# <a href="/salary-negotiation-guide">Salary Negotiation Guide</a>
# </div>
# <div class="navItem">
# <a href="/payscale-index/">The PayScale Index</a>
# </div>
# <div class="navItem">
# <a href="/data-packages">Data Packages</a>
# </div>
# <div class="navItem">
# <a href="/data-visualizations">Data Visualizations</a>
# </div>
# <div class="navCategory">
# <a href="/education">Education</a>
# </div>
# <div class="navItem">
# <a href="/college-roi/">College ROI Report</a>
# </div>
# <div class="navItem">
# <a href="/college-salary-report">College Salary Report</a>
# </div>
# <div class="navCategory">
# <a href="/Job-Search-Engine">Find Jobs</a>
# </div>
# </div>
# <div class="menuColumn whatsYourWorthAd" id="menuAdRight">
# <h3 class="whatsYourWorthHeadline">What are you worth?</h3>
# <div class="whatsYourWorthText">
#                   Find out what you
#                   <br/>
#                   should be paid.
#                 </div>
# <a href="/startwizard.aspx?starttype=Header">
# <span class="primaryButton">
#                     Get a Free <br/>Salary Report
#                   </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="menuTop" id="business">
# <a class="menuLink" href="/hr">
# <span class="menuItem" id="psHeaderBusiness">
#             BUSINESS<span class="menuItemBlurb">What should I pay?</span>
# </span>
# </a>
# <div class="flyout">
# <div class="flyoutBody">
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/hr">Compensation Software</a>
# </div>
# <div class="navItem">
# <a href="/hr/video">Tour</a>
# </div>
# <div class="navCategory">
# <a href="/hr/product-insight-expert">Products</a>
# </div>
# <div class="navCategory">
# <a href="/hr/customers">Customers</a>
# </div>
# <div class="navCategory">
# <a href="/industries">Industries</a>
# </div>
# <div class="navCategory">
# <a href="/hr/services">Services</a>
# </div>
# </div>
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/hr/resources">Resources</a>
# </div>
# <div class="navItem">
# <a href="/hr/resources">Compensation Resources</a>
# </div>
# <div class="navItem">
# <a href="/hr/product-how-it-works">Methodology</a>
# </div>
# <div class="navItem">
# <a href="/cbpr">Best Practices Research</a>
# </div>
# <div class="navItem">
# <a href="/hr/tools">ROI Calculators</a>
# </div>
# <div class="navCategory">
# <a href="/compensation-today">Blog</a>
# </div>
# <div class="navCategory">
# <a href="/hr/startwizard?starttype=Header">Price a Job</a>
# </div>
# <div class="navCategory">
# <a href="http://resources.payscale.com/hr-request-a-demo.html">Demo</a>
# </div>
# <div class="navCategory">
# <a href="/hr/whypayscale/support">Support</a>
# </div>
# </div>
# <div class="menuColumn latestCompTrendsAd" id="menuAdRight">
# <a href="/cbpr">
# <img alt="PayScale Compensation Best Practices" height="303" src="https://cdn-payscale.com/content/cbpr/2017/ad_CBPR_nav_237x303.png" width="237"/>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="menuTop" id="about">
# <a class="menuLink" href="/about">
# <span class="menuItem" id="psHeaderAbout">
#             ABOUT<span class="menuItemBlurb">Who we are.</span>
# </span>
# </a>
# <div class="flyout">
# <div class="flyoutBody">
# <div class="menuColumn compVideoAd" id="menuAdLeft">
# <a href="/hr/video">
# <img alt="Take a tour of PayScale!" height="135" src="https://cdn-payscale.com/cms-images/default-source/b2b/img_video.png?sfvrsn=2" width="243"/>
# </a>
# <p class="compVideoAdBlurb">
#                   Got a minute?
#                 </p>
# </div>
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/about">Who We Are</a>
# </div>
# <div class="navItem">
# <a href="/about/management-team">Executive Team</a>
# </div>
# <div class="navItem">
# <a href="/about/board-of-directors">Board of Directors</a>
# </div>
# <div class="navCategory">
# <a href="/about/methodology">Methodology</a>
# </div>
# <div class="navCategory linkJobListing">
# <a href="/about/jobs">Work For Us</a>
# </div>
# </div>
# <div class="menuColumn">
# <div class="navCategory">
# <a href="/about/latest-news">PayScale in the News</a>
# </div>
# <div class="navCategory">
# <a href="/about/press-releases">Press Releases</a>
# </div>
# <div class="navCategory">
# <a href="/about/press-kit">Press Kit</a>
# </div>
# <div class="navCategory">
# <a href="/hr/partners">Partners</a>
# </div>
# <div class="navCategory">
# <a href="/about/use-our-data">Use Our Data</a>
# </div>
# <div class="navCategory">
# <a href="/about/contact">Contact</a>
# </div>
# </div>
# <div class="menuColumn whatsYourWorthAd" id="menuAdRight">
# <a href="/hr/video">
# <img alt="Take a tour of PayScale!" height="135" src="https://cdn-payscale.com/cms-images/default-source/b2b/img_video.png?sfvrsn=2" width="243"/>
# </a>
# <p class="compVideoAdBlurb">
#                 Got a minute?
#               </p>
# </div>
# </div>
# </div>
# </li>
# <li class="rightSideNav menuTop" id="phone">
# <a href="tel:+1-888-219-0327" style="display:block; width=100%;">
# <span class="menuItemStatic" id="psHeaderPhoneCon">
# <div class="telephone"></div>
# <span>1.888.219.0327</span>
# </span>
# </a>
# </li>
# <li class="rightSideNav menuTop loginOption out" id="loggedin">
# <span class="menuItemStatic" id="loginContainer">
# <a class="menuLink allowNav" href="https://www.payscale.com/login.aspx">
# <span>LOGIN</span>
# </a>
# </span>
# </li>
# <li class="rightSideNav menuTop loginOption in" id="loggedout">
# <span class="menuItemStatic menuLink" id="loggedInContainer">
# <div class="star"></div>
# <span id="loggedInUsername"></span>
# </span>
# <div class="smallMenu" style="width: 150px">
# <div class="smallMenuBody" id="loginMenuBusiness">
# <div>
# <a href="/redir.aspx?site=insight&amp;url=/dashboard.aspx">My Dashboard</a>
# </div>
# <div style="min-height: 10px;">
# </div>
# <div>
# <a href="/mypayscale.aspx">My Salary Reports</a>
# </div>
# <div>
# <a href="https://www.payscale.com/myaccount.aspx">My Account</a>
# </div>
# <div>
# <a href="/logout.aspx">Log Out</a>
# </div>
# </div>
# <div class="smallMenuBody" id="loginMenuPersonal">
# <div>
# <a href="/mypayscale.aspx">My Salary Reports</a>
# </div>
# <div>
# <a href="https://www.payscale.com/myaccount.aspx">My Account</a>
# </div>
# <div>
# <a href="/logout.aspx">Log Out</a>
# </div>
# </div>
# <div class="smallMenuBody" id="loginMenuAbout">
# <div>
# <a href="/mypayscale.aspx">My Salary Reports</a>
# </div>
# <div>
# <a href="https://www.payscale.com/myaccount.aspx">My Account</a>
# </div>
# <div>
# <a href="/logout.aspx">Log Out</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <div class="clear"></div>
# </div>
# <div class="headerBottomBorder"></div>
# </div>
# <span class="dynamicContentEnd hidden" data-content="/header-footer/header"></span>
# </div>
# <span class="dynamicContentBegin hidden" data-content="/include_facebook_sdk"></span><div id="fb-root"></div>
# <span class="dynamicContentEnd hidden" data-content="/include_facebook_sdk"></span>
# <link href="//fonts.googleapis.com/css?family=Roboto+Slab:700" rel="stylesheet" type="text/css"/>
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-sm-6">
# <ol class="breadcrumb">
# <li class="active" id="ctl00_mainContent_collegeRoiControl__bc3">
# <span id="ctl00_mainContent_collegeRoiControl__bc3text">College ROI</span></li>
# </ol>
# </div>
# <div class="col-xs-12 col-sm-6">
# <div class="pull-left" style="margin: 0;">
# <iframe allowtransparency="true" frameborder="0" scrolling="no" src="http://www.facebook.com/plugins/like.php?href=http://www.payscale.com/college-roi?page=120&amp;layout=button_count&amp;show_faces=false&amp;width=100&amp;action=like&amp;colorscheme=light&amp;height=21" style="border: none; overflow: hidden; width: 100px; height: 21px;"></iframe>
# </div>
# <div class="pull-left" style="width: 100px;">
# <script data-counter="right" type="in/share"></script>
# </div>
# <div class="pull-left" style="width:100px;">
# <g:plusone count="true" href="http://www.payscale.com/college-roi?page=120" size="medium">
# </g:plusone>
# </div>
# <div class="pull-left" style="width:100px;">
# <a class="twitter-share-button" data-count="horizontal" data-related="https://twitter.com/payscale" data-via="payscale" href="http://twitter.com/share">Tweet</a>
# </div>
# <div class="pull-left" style="width: 70px;">
# <a data-pin-config="beside" data-pin-do="buttonPin" href="//www.pinterest.com/pin/create/button/?url=http://www.payscale.com/college-roi?page=120&amp;media=//cdn-payscale.com//content/roi/2015_pinterest.png&amp;description=Next%20stop%3A%20Pinterest">
# <img src="//assets.pinterest.com/images/pidgets/pinit_fg_en_rect_gray_20.png"/></a>
# <!-- Please call pinit.js only once per page -->
# </div>
# </div>
# </div>
# <span class="dynamicContentBegin hidden" data-content="/college-roi-2017/header"></span>
# <div class="row">
# <div class="col-xs-12 col-sm-12 col-md-8">
# <span class="dynamicContentBegin hidden" data-content="roi2017-header"></span>
# <style type="text/css">
#
# .subNavTextLineOne {
# 	left: 50px;
# 	line-height: 40px;
# }
#
# .dropdown-menu li a {
#     padding: 3px 16px;
# }
#
# </style>
# <div class="row">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <!-- Content Navigation -->
# <div class="row">
# <div class="col-xs-12">
# <!-- Desktop Image -->
# <div class="row hidden-sm hidden-xs">
# <div class="col-xs-12">
# <a href="/college-roi">
# <img class="img-responsive col-xs-12 margin-bottom-xs" src="https://cdn-payscale.com/content/roi/2017/CollegeROI_2017_637x100.jpg"/>
# <span class="subNavTextLineOne"></span>
# <span class="subNavTextLineTwo"></span>
# </a>
# </div>
# </div>
# <!-- Tablet Image -->
# <div class="row visible-sm-block">
# <div class="col-xs-12">
# <a href="/college-roi">
# <img class="img-responsive col-xs-12 margin-bottom-xs" src="https://cdn-payscale.com/content/roi/2017/CollegeROI_2017_1006x148.jpg"/>
# </a>
# </div>
# </div>
# <!-- Mobile Image -->
# <div class="row visible-xs-block">
# <div class="col-xs-12">
# <a href="/college-roi">
# <img class="img-responsive col-xs-12 margin-bottom-xs" src="https://cdn-payscale.com/content/roi/2017/CollegeROI_2017_767x142.jpg"/>
# </a>
# </div>
# </div>
# <!-- Sub Navigation Buttons -->
# <div class="row navBarButtons">
# <div class="col-sm-4"><div class="dropdown"><a aria-expanded="false" class="btn btn-block dropdown-toggle btn-nav" data-toggle="dropdown" href="#" id="state_schooltype" role="button"><span class="text-center"><strong>BEST ROI LISTS</strong></span><span class="caret"></span></a><ul class="dropdown-menu" role="menu">
# <li role="presentation"><a class="" href="/college-roi" role="menuitem" tabindex="-1">View the Complete List</a></li>
# <li role="presentation"><a class="" href="/college-roi/state" role="menuitem" tabindex="-1">Best ROI by State</a></li>
# <li role="presentation"><a class="" href="/college-roi/school-type" role="menuitem" tabindex="-1">Best ROI by School Type</a></li>
# <li role="presentation"><a class="" href="/college-roi/major" role="menuitem" tabindex="-1">Best ROI by Major</a></li>
# <li role="presentation"><a class="" href="/college-roi/job" role="menuitem" tabindex="-1">Best ROI by Job</a></li>
# </ul></div></div>
# <div class="col-sm-4"><div class="dropdown"><a aria-expanded="false" class="btn btn-block dropdown-toggle btn-nav" data-toggle="dropdown" href="#" id="major_job" role="button"><span class="text-center"><strong>ARTICLES &amp; CHARTS</strong></span><span class="caret"></span></a><ul class="dropdown-menu" role="menu">
# <li role="presentation"><a class="" href="/college-roi/roi-by-household-income" role="menuitem" tabindex="-1">Household Income</a></li>
# <li role="presentation"><a class="" href="/college-roi/public-school-roi" role="menuitem" tabindex="-1">Public School ROI</a></li>
# <li role="presentation"><a class="" href="/college-roi/best-college-in-every-state" role="menuitem" tabindex="-1">Best School by State</a></li>
# <li role="presentation"><a class="" href="/college-roi/forecast" role="menuitem" tabindex="-1">Forecast</a></li>
# <li role="presentation"><a class="" href="/college-roi/value-of-education" role="menuitem" tabindex="-1">The Value of Education</a></li>
# </ul></div></div>
# <div class="col-sm-4"><div class="dropdown"><a aria-expanded="false" class="btn btn-block dropdown-toggle btn-nav" data-toggle="dropdown" href="#" id="full_list_more" role="button"><span class="text-center"><strong>FOR SCHOOLS</strong></span><span class="caret"></span></a><ul class="dropdown-menu" role="menu">
# <li role="presentation"><a class="" href="/college-roi/methodology" role="menuitem" tabindex="-1">Methodology</a></li>
# <li role="presentation"><a class="" href="/college-roi/faqs" role="menuitem" tabindex="-1">FAQs</a></li>
# <li role="presentation"><a class="" href="/college-roi/badges" role="menuitem" tabindex="-1">School Badges</a></li>
# </ul></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     if($("#activeSubNavLink").length > 0) {
#         $("#activeSubNavLink").parent().parent().find('a').addClass('active');
#     }
# </script><span class="dynamicContentEnd hidden" data-content="roi2017-header"></span>
# </div>
# <div class="col-md-4 hidden-xs hidden-sm">
# <span class="dynamicContentBegin hidden" data-content="roi2017-survey-start-corner"></span><div style="border:1px solid #CECECE; font-size:20px; text-align:center; padding:12px; min-height:141px; width:300px">
#     Find Out Exactly What You<br/>
#     Should Be Paid<br/>
# <a href="/wizards/choose.aspx?TK=ROI2017"><button class="btn btn-primary block-center" style="margin-top:6px" type="button">Get a free salary report »</button></a>
# </div><span class="dynamicContentEnd hidden" data-content="roi2017-survey-start-corner"></span>
# </div>
# </div>
# <span class="dynamicContentEnd hidden" data-content="/college-roi-2017/header"></span>
# <div class="row">
# <div class="col-xs-12">
# <h1>
# <span id="ctl00_mainContent_collegeRoiControl__title">College ROI Report: Best Value Colleges</span></h1>
# <p>
# <span id="ctl00_mainContent_collegeRoiControl__introStart"><p>With the average college student graduating with tens-of-thousands of dollars in student loans, prospective college students, parents and policymakers are all trying to better understand the value of college education, particularly as it applies to future decisions in the job market.  <a href="javascript: void(0);" onclick="$('html,body').animate({ scrollTop: $('.introReadMore').offset().top - 50 }, 0);">Read More</a></p></span>
# </p>
# </div>
# </div>
# <div class="row visible-xs-block visible-sm-block">
# <div class="col-xs-12">
# <span class="dynamicContentBegin hidden" data-content="/college-roi-2017/surveyStart"></span>
# <div style="border:1px solid #CECECE  ; font-size:22px; text-align:center; padding:12px; min-height:141px">
#     Find Out Exactly What You<br/>
#     Should Be Paid<br/>
# <a href="/wizards/choose.aspx?TK=ROI2017"><button class="btn btn-primary block-center" style="margin-top:6px" type="button">Get a free salary report »</button></a>
# </div><span class="dynamicContentEnd hidden" data-content="/college-roi-2017/surveyStart"></span>
# </div>
# </div>
# <div id="collegeRoiContent">
# <div id="react1"><div class="row" data-react-checksum="-348109691" data-reactid=".isppni4e2u"><div class="col-sm-12" data-reactid=".isppni4e2u.0"><div class="row" data-reactid=".isppni4e2u.0.0"><div class="col-xs-12 col-sm-3" data-reactid=".isppni4e2u.0.0.0"><div class="margin-bottom-xs" data-reactid=".isppni4e2u.0.0.0.0"><label class="small" data-reactid=".isppni4e2u.0.0.0.0.0">On Campus</label><br data-reactid=".isppni4e2u.0.0.0.0.1"/><div class="btn-group btn-group-justified" data-reactid=".isppni4e2u.0.0.0.0.2"><a class="btn btn-default btn-sm active" data-reactid=".isppni4e2u.0.0.0.0.2.0" href="javascript:void(0);">On</a><a class="btn btn-default btn-sm" data-reactid=".isppni4e2u.0.0.0.0.2.1" href="javascript:void(0);">Off</a></div></div></div><div class="col-xs-12 col-sm-3" data-reactid=".isppni4e2u.0.0.1"><div class="margin-bottom-xs" data-reactid=".isppni4e2u.0.0.1.0"><label class="small" data-reactid=".isppni4e2u.0.0.1.0.0">Financial Aid</label><br data-reactid=".isppni4e2u.0.0.1.0.1"/><div class="btn-group btn-group-justified" data-reactid=".isppni4e2u.0.0.1.0.2"><a class="btn btn-default btn-sm active" data-reactid=".isppni4e2u.0.0.1.0.2.0" href="javascript:void(0);">Without</a><a class="btn btn-default btn-sm" data-reactid=".isppni4e2u.0.0.1.0.2.1" href="javascript:void(0);">With</a></div></div></div><div class="col-xs-12 col-sm-3" data-reactid=".isppni4e2u.0.0.2"><div class="margin-bottom-xs" data-reactid=".isppni4e2u.0.0.2.0"><label class="small" data-reactid=".isppni4e2u.0.0.2.0.0">ROI Type</label><br data-reactid=".isppni4e2u.0.0.2.0.1"/><div class="btn-group btn-group-justified" data-reactid=".isppni4e2u.0.0.2.0.2"><a class="btn btn-default btn-sm active" data-reactid=".isppni4e2u.0.0.2.0.2.0" href="javascript:void(0);">20-Yr Net</a><a class="btn btn-default btn-sm" data-reactid=".isppni4e2u.0.0.2.0.2.1" href="javascript:void(0);">Annual %</a></div></div></div><div class="col-xs-12 col-sm-3" data-reactid=".isppni4e2u.0.0.3"><label class="hidden-xs" data-reactid=".isppni4e2u.0.0.3.0"> </label><div data-reactid=".isppni4e2u.0.0.3.1" id="search_bloodhound"><input autocomplete="off" class="form-control typeahead input-sm margin-bottom-xs" data-reactid=".isppni4e2u.0.0.3.1.0" id="roiSearch" placeholder="Find a School by Name" type="text"/></div></div></div><div data-reactid=".isppni4e2u.0.1"><table class="table table-bordered table-striped table-condensed" data-reactid=".isppni4e2u.0.1.0"><thead class="hidden-xs" data-reactid=".isppni4e2u.0.1.0.0"><tr data-reactid=".isppni4e2u.0.1.0.0.0"><th class="text-center datatable-header" data-reactid=".isppni4e2u.0.1.0.0.0.$RankText_header"><span data-reactid=".isppni4e2u.0.1.0.0.0.$RankText_header.0">Rank</span><span data-reactid=".isppni4e2u.0.1.0.0.0.$RankText_header.1"> </span><noscript data-reactid=".isppni4e2u.0.1.0.0.0.$RankText_header.2"></noscript><noscript data-reactid=".isppni4e2u.0.1.0.0.0.$RankText_header.3"></noscript></th><th class="text-center datatable-header" data-reactid=".isppni4e2u.0.1.0.0.0.$Name_header"><span data-reactid=".isppni4e2u.0.1.0.0.0.$Name_header.0">School Name</span><span data-reactid=".isppni4e2u.0.1.0.0.0.$Name_header.1"> </span><noscript data-reactid=".isppni4e2u.0.1.0.0.0.$Name_header.2"></noscript><noscript data-reactid=".isppni4e2u.0.1.0.0.0.$Name_header.3"></noscript></th><th class="text-center datatable-header hidden" data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header"><span data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header.0">Annual ROI</span><span data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header.1"> </span><span data-placement="left" data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header.2" data-toggle="tooltip" title="20 Year ROI annualized to represent the % of expected ROI received each year after graduation."><span aria-hidden="true" class="glyphicon glyphicon-question-sign" data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header.2.0"></span></span><noscript data-reactid=".isppni4e2u.0.1.0.0.0.$AnnRoiOn_header.3"></noscrip ...
# </div>
# <p>
# <span id="ctl00_mainContent_collegeRoiControl__introMore"><div class="introReadMore"><p>This isn't to say that students should only pursue majors with the highest earning potential or make decisions about where to attend school based solely off College ROI Report rankings. But it makes sense to provide as much information as possible to 18-year-olds signing on the dotted line for student loans loans they may not even be certain they can pay back. Access to data showing how other alumni following a similar path have fared in the job market is critical to ensuring students are making financial decisions that make sense.</p><p></p><h2>Sticker Price vs. Your Cost to Attend</h2><p>One big variable in calculating best college values in monetary terms is the cost to attend. Unfortunately, it can be fairly difficult to discern what your true net cost might be. The stated "sticker price" that colleges report to the Department of Education is often not representative of what a majority of students will pay. In a <i>Washington Post</i> article, author and higher ed pundit Jeffrey Selingo wrote "If colleges continue to maintain that so few people actually pay the sticker price, then maybe it's time for them to stop advertising it and develop a new pricing approach that is more realistic and transparent for more of their students."</p> <p>Colleges will often reduce a student's cost, by supplying financial aid assistance, based on family income and academic success in high school. Schools are required to provide access to <a href="https://www.collegeraptor.com">net price calculators</a> so that students can estimate their true cost to attend, but not all students are even aware these calculators exist.</p> <p>"This information gap matters," stated a November 2014 report titled <i>Transparency in College Costs</i> from the Brookings Institution. "Research suggests that providing more information to prospective students regarding what it would actually cost to attend will have a substantive impact on their higher-education decision making."</p> <p></p><h2>Student Loan Debt Is Reaching Crisis Levels</h2> <p>In the past, college was a ticket to a brighter future. Now, it's a ticket to immense debt and an uncertain financial future for far too many students.* Student loan debt in the U.S. has now topped $1 trillion. According to the <a href="http://www.newyorkfed.org/research/current_issues/ci20-1.pdf">Federal Reserve Bank of New York</a>, 44 percent of recent college graduates are underemployed  -- working in jobs that don't require their degree  --  as of 2012. </p><p>In a report to Congress, then-Fed Chairwoman Janet Yellen talked about the struggles of the Millennial generation saying "They're certainly waiting longer to buy houses, to get married. They have a lot of student debt. They seem quite worried about housing as an investment. They've had a tough time in the job market." </p><p>Those delays could have a serious impact on the U.S. economy as a whole and specifically the housing market. Derek Thompson of <a href="http://www.theatlantic.com/business/archive/2014/07/millennials-trends-housing/373892"><i>The Atlantic</i></a> wrote in 2014 "More years of school + more student debt + lower starting salaries + a nervous housing market + stricter rules for new home-buyers = no new home-buyers." </p><p></p><h2>College Return on Investment</h2><p>No matter how you look at it, college is an investment -- both of time and money. The benefit to this particular investment is that there are returns far beyond the obvious monetary ones. However, the financial aspects of evaluating college return on investment cannot be ignored. And some schools are simply doing a better job of setting their alumni up for success in the job market. Whether you're planning to study computer science or psychology, earning potential in your chosen field, along with the cost of attendance for the schools you're considering, should be part of the equation when whittling d ...
# </p>
# <div class="fb-comments" data-href="http://www.payscale.com/college-roi-2017" data-num-posts="10" data-width="100%" id="_comment" style="clear: both"></div>
# </div>
# <div class="Payscale_Footer">
# <div class="ilwidget ilwidget_margin-top-lg" style="background-color: #f8f8f6">
# <div class="ilwidget_container ilwidget_padding-bottom ilwidget_padding-top" id="ctl00_m_StandardFooter_ilwidget_ILWidgetContainer">
# <div class="ilwidget_row">
# <div class="ilwidget_col-lg-12">
# <div class="ilwidget_row ilwidget_margin-bottom-xs">
# <div class="ilwidget_col-xs-12 ilwidget_col-sm-2">
# <span class="ilwidget_small"><strong>HR Professionals</strong></span>
# </div>
# <div class="ilwidget_col-xs-12 ilwidget_col-sm-10">
# <a class="ilwidget_small" href="/about/use-our-data">Compensation Data</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/compensation-today">HR News</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/cbpr">Compensation Practices</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/hr">Compensation Management Software</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/hr/customers">Compensation Software Reviews</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/hr/partners">HR Partners</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/hr/product-benchmark">Salary Benchmarking</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/hr/product-insight-expert">HR Software</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries">Compensation By Industry</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/transportation">Transportation Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/oil">Oil Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/technology">Technology Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/insurance">Insurance Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/professional-services">Professional Services Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/healthcare">Healthcare Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/manufacturing">Manufacturing Compensation</a><span class="ilwidget_hideLast"> | </span><a class="ilwidget_small" href="/industries/education">Education Compensation</a><span class="ilwidget_hideLast"> | </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <span class="dynamicContentBegin hidden" data-content="/header-footer/footer"></span><div id="psFooterCon">
# <div id="psFooter">
# <div id="psFooterBody">
# <div id="psFooterLinks">
# <div class="psFooterCol">
# <div class="takeSurveyAd">
# <a href="/wizards/choose.aspx?TK=FooterTakeSurveyAd">
# <img alt="Take the survey and earn more money" height="186" src="https://cdn-payscale.com/content/header-footer/take_survey_ad.png" width="220"/>
# </a>
# </div>
# <div class="viewProductsAd">
# <a href="/hr/product-insight-expert">
# <img alt="Explore PayScale's cloud compensation software" height="177" src="https://cdn-payscale.com/content/header-footer/product_footer_ad.png" width="189"/>
# </a>
# </div>
# </div>
# <div class="psFooterCol">
# <div class="navCategory">
#             BUSINESS
#           </div>
# <div class="navItem">
# <a href="/hr">Compensation Software</a>
# </div>
# <div class="navItem">
# <a href="/hr/whitepapers">Whitepapers</a>
# </div>
# <div class="navItem">
# <a href="/hr/webinars">Webinars</a>
# </div>
# <div class="navItem">
# <a href="/hr/customers">Customers</a>
# </div>
# <div class="navItem">
# <a href="/hr/whypayscale/support">Support</a>
# </div>
# <div class="navItem">
# <a href="http://resources.payscale.com/hr-request-a-demo.html">Request a Demo</a>
# </div>
# </div>
# <div class="psFooterCol">
# <div class="navCategory">
#             PERSONAL
#           </div>
# <div class="navItem">
# <a href="/mypayscale.aspx">Get Your Salary Report</a>
# </div>
# <div class="navItem">
# <a href="/Job-Search-Engine">Find a Job</a>
# </div>
# <div class="navItem">
# <a href="/research/US/Country=United_States/Salary">Research Careers</a>
# </div>
# <div class="navCategory">
#             BLOGS
#           </div>
# <div class="navItem">
# <a href="/career-news">Career News</a>
# </div>
# <div class="navItem">
# <a href="/compensation-today">Compensation Today</a>
# </div>
# </div>
# <div class="psFooterCol">
# <div class="navCategory">
#             ABOUT
#           </div>
# <div class="navItem">
# <a href="/about">About PayScale</a>
# </div>
# <div class="navItem">
# <a href="http://marketpay.payscale.com/">About MarketPay</a>
# </div>
# <div class="navItem linkJobListing">
# <a href="/about/jobs">Jobs at PayScale</a>
# </div>
# <div class="socialMediaLinks">
# <a href="https://www.facebook.com/PayScale" rel="nofollow">
# <img alt="Facebook" height="26" src="https://cdn-payscale.com/images/footer/facebook_26x26.png" width="26"/>
# </a>
# <a href="https://twitter.com/payscale" rel="nofollow">
# <img alt="Twitter" height="26" src="https://cdn-payscale.com/images/footer/twitter_26x26.png" width="26"/>
# </a>
# <a href="https://www.linkedin.com/company/47199" rel="nofollow">
# <img alt="LinkedIn" height="26" src="https://cdn-payscale.com/images/footer/linkedin_26x26.png" width="26"/>
# </a>
# <a href="https://plus.google.com/+payscale" rel="nofollow">
# <img alt="Google Plus" height="26" src="https://cdn-payscale.com/images/footer/gplus_26x26.png" width="26"/>
# </a>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="psFooterHubLinks">
#         Browse by: <a href="/hub/US/Job">Jobs</a>, <a href="/hub/US/Employer">Employers</a>, <a href="/hub/US/Degree">Degrees</a>
# </div>
# <div class="privacyCon">
# <div class="privacyNotice">
# <img alt="" height="14" src="https://cdn-payscale.com/content/header-footer/lock-icon.png" width="11"/>
#           Privacy Notice: PayScale takes your privacy seriously and is sensitive to the nature of information collected on this site.
#         </div>
# <div class="privacyLinks" style="margin-top:16px">
# <a href="/license" rel="nofollow">Terms of Use</a>
# <span class="privacyLinkDivider">|</span>
# <a href="/privacy.aspx" rel="nofollow">Privacy Policy</a>
# </div>
# <div class="copyright">
#           © 2017 PayScale, Inc. All rights reserved | 1000 1st Ave South, Seattle, WA 98134
#         </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="psFooterBottom"></div>
# </div><span class="dynamicContentEnd hidden" data-content="/header-footer/footer"></span>
# </div>
# <script></script>
# <div id="pageBottom"></div>
# <div id="m_jsIncludes" style="display:none;">
# </div>
# <script>
#
#     window.pageType = 1;
#
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId                 : '355988364493140',
#             status                : true,
#             cookie                : true,
#             xfbml                 : true,
#             oauth                 : true,
#             frictionlessRequests  : true,
#             version               : 'v2.7'
#         });
#     };
#
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#
#         var metadata = {"key":["Name","Tuition"],"thenSortBy":"Name","columns":[{"text":"Rank","data":"RankText","sortData":"Rank","defaultSortOrder":"a","mobile":"hide"},{"text":"School Name","data":"Name","defaultSortOrder":"a","preUrl":"/research/US/School=","url":"Url","label":"Tuition","preImage":"//cdn-payscale.com/content/school_logos/","image":"Img","mobile":"header-counter","mobileCounter":"RankText"},{"text":"Annual ROI","data":"AnnRoiOn","dataType":"percentString","sortType":"float","filters":["annualRoi","onCampus"],"negatedFilters":["withFinAid"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiOff","dataType":"percentString","sortType":"float","filters":["annualRoi"],"negatedFilters":["withFinAid","onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiAidOn","dataType":"percentString","sortType":"float","filters":["annualRoi","withFinAid","onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiAidOff","dataType":"percentString","sortType":"float","filters":["annualRoi","withFinAid"],"negatedFilters":["onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"20 Year Net ROI","data":"RoiOn","dataType":"currencyString","sortType":"float","filters":["onCampus"],"negatedFilters":["annualRoi","withFinAid"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiOff","dataType":"currencyString","sortType":"float","filters":[],"negatedFilters":["onCampus","annualRoi","withFinAid"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiAidOn","dataType":"currencyString","sortType":"float","filters":["onCampus","withFinAid"],"negatedFilters":["annualRoi"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiAidOff","dataType":"currencyString","sortType":"float","filters":["withFinAid"],"negatedFilters":["annualRoi","onCampus"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"Total 4 Year Cost","data":"CostOn","dataType":"currencyString","sortType":"float","filters":["onCampus"],"defaultSortOrder":"a","tooltip":"Full cost, including tuition & fees, room & board, and books & supplies. Actual net cost may vary based on a student’s academic success and family income. Source: IPEDS"},{"text":"Total 4 Year Cost","data":"CostOff","dataType":"currencyString","sortType":"float","negatedFilters":["onCampus"],"defaultSortOrder":"a","tooltip":"Full cost, including tuition & fees, room & board, and books & supplies. Actual net cost may vary based on a student’s academic success and family income. Source: IPEDS"},{"text":"Graduation Rate","data":"GradRate","dataType":"percentString","sortType":"float","defaultSortOrder":"d","mobileText":"Grad Rate","tooltip":"% of full-time, first-time degree seeking undergrad students who began their studies at the given school and graduate within 6 years. Source: IPEDS"},{"text":"Typical Years to Graduate","data":"GradTime","defaultSortOrder":"a","mobileText":"Time to Graduate","tooltip":"# of years it takes for at least 65 percent of graduates from a given school to receive their diplomas. ...
#         var collegeRoiData = [{"Name":"Adams State College","CostOn":"$80,400","CostOff":"$83,400","RoiOn":"$93,000","RoiOff":"$90,000","RoiAidOn":"$126,000","RoiAidOff":"$123,000","AnnRoiOn":"3.9%","AnnRoiOff":"3.7%","AnnRoiAidOn":"6.7%","AnnRoiAidOff":"6.3%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(In-State)"},{"Name":"Adams State College","CostOn":"$123,000","CostOff":"$126,000","RoiOn":"$50,100","RoiOff":"$47,100","RoiAidOn":"$82,700","RoiAidOff":"$79,700","AnnRoiOn":"1.7%","AnnRoiOff":"1.6%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"3.1%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Adelphi University","CostOn":"$194,000","CostOff":"$194,000","RoiOn":"$292,000","RoiOff":"$293,000","RoiAidOn":"$362,000","RoiAidOff":"$362,000","AnnRoiOn":"4.7%","AnnRoiOff":"4.7%","AnnRoiAidOn":"7.1%","AnnRoiAidOff":"7.1%","GradRate":"64%","GradTime":"4 Years","Grant":"93%","LoanAmt":"$33,300","Url":"Adelphi_University/Salary","Img":"Adelphi University_50px.png","Tuition":"(Private)"},{"Name":"Adrian College","CostOn":"$177,000","CostOff":"$164,000","RoiOn":"($56,200)","RoiOff":"($42,700)","RoiAidOn":"$29,300","RoiAidOff":"$42,700","AnnRoiOn":"-1.9%","AnnRoiOff":"-1.5%","AnnRoiAidOn":"1.4%","AnnRoiAidOff":"2.2%","GradRate":"57%","GradTime":"4 Years","Grant":"98%","LoanAmt":"$30,800","Url":"Adrian_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Agnes Scott College","CostOn":"$192,000","CostOff":"$159,000","RoiOn":"($23,100)","RoiOff":"$9,700","RoiAidOn":"$81,000","RoiAidOff":"$114,000","AnnRoiOn":"-0.6%","AnnRoiOff":"0.3%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"5.7%","GradRate":"73%","GradTime":"4 Years","Grant":"100%","LoanAmt":"$28,300","Url":"Agnes_Scott_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$111,000","CostOff":"$114,000","RoiOn":"$203,000","RoiOff":"$201,000","RoiAidOn":"$234,000","RoiAidOff":"$231,000","AnnRoiOn":"5.3%","AnnRoiOff":"5.2%","AnnRoiAidOn":"7.0%","AnnRoiAidOff":"6.8%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$72,400","CostOff":"$83,500","RoiOn":"$34,500","RoiOff":"$23,400","RoiAidOn":"$71,000","RoiAidOff":"$59,800","AnnRoiOn":"2.0%","AnnRoiOff":"1.2%","AnnRoiAidOn":"5.6%","AnnRoiAidOff":"4.2%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(In-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$99,500","CostOff":"$111,000","RoiOn":"$7,400","RoiOff":"($3,800)","RoiAidOn":"$43,800","RoiAidOff":"$32,700","AnnRoiOn":"0.4%","AnnRoiOff":"-0.2%","AnnRoiAidOn":"2.7%","AnnRoiAidOff":"1.8%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(Out-of-State)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$84,700","CostOff":"$87,600","RoiOn":"$230,000","RoiOff":"$227,000","RoiAidOn":"$260,000","RoiAidOff":"$257,000","AnnRoiOn":"6.8%","AnnRoiOff":"6.6%","AnnRoiAidOn":"9.2%","AnnRoiAidOff":"8.9%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(In-State)"},{"Name":"Albany State University","CostOn":"$122,000","CostOff":"$129,000","RoiOn":"($38,900)","RoiOff":"($46,400)","RoiAidOn":"($14,000)","RoiAidOff":"($21,500)","AnnRoiOn":"-1.9%","AnnRoiOff":"-2.2%","AnnRoiAidOn":"-0.8%","AnnRoiAidOff":"-1.1%","GradRate":"40%","Grad ...
#
#     </script>
# <div id="m_schema" style="display:none;">
# </div>
# </body>
# </html>

# %% [markdown]
# Let's find the ROI data.

# %%
roi_data = soup.find('script', text=re.compile('collegeRoiData'))

# %% [markdown]
# `soup.find` returns the element that contains the string `collegeRoiData`.
# Let's have a look.

# %%
print(roi_data)
# Out:
# <script>
#
#     window.pageType = 1;
#
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId                 : '355988364493140',
#             status                : true,
#             cookie                : true,
#             xfbml                 : true,
#             oauth                 : true,
#             frictionlessRequests  : true,
#             version               : 'v2.7'
#         });
#     };
#
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#
#         var metadata = {"key":["Name","Tuition"],"thenSortBy":"Name","columns":[{"text":"Rank","data":"RankText","sortData":"Rank","defaultSortOrder":"a","mobile":"hide"},{"text":"School Name","data":"Name","defaultSortOrder":"a","preUrl":"/research/US/School=","url":"Url","label":"Tuition","preImage":"//cdn-payscale.com/content/school_logos/","image":"Img","mobile":"header-counter","mobileCounter":"RankText"},{"text":"Annual ROI","data":"AnnRoiOn","dataType":"percentString","sortType":"float","filters":["annualRoi","onCampus"],"negatedFilters":["withFinAid"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiOff","dataType":"percentString","sortType":"float","filters":["annualRoi"],"negatedFilters":["withFinAid","onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiAidOn","dataType":"percentString","sortType":"float","filters":["annualRoi","withFinAid","onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"Annual ROI","data":"AnnRoiAidOff","dataType":"percentString","sortType":"float","filters":["annualRoi","withFinAid"],"negatedFilters":["onCampus"],"defaultSortOrder":"d","tooltip":"20 Year ROI annualized to represent the % of expected ROI received each year after graduation."},{"text":"20 Year Net ROI","data":"RoiOn","dataType":"currencyString","sortType":"float","filters":["onCampus"],"negatedFilters":["annualRoi","withFinAid"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiOff","dataType":"currencyString","sortType":"float","filters":[],"negatedFilters":["onCampus","annualRoi","withFinAid"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiAidOn","dataType":"currencyString","sortType":"float","filters":["onCampus","withFinAid"],"negatedFilters":["annualRoi"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"20 Year Net ROI","data":"RoiAidOff","dataType":"currencyString","sortType":"float","filters":["withFinAid"],"negatedFilters":["annualRoi","onCampus"],"defaultSortOrder":"d","tooltip":"Difference between 20 Year Median Pay for a bachelor’s grad and 24 Year Median Pay for a high school grad minus Total 4 Year Cost."},{"text":"Total 4 Year Cost","data":"CostOn","dataType":"currencyString","sortType":"float","filters":["onCampus"],"defaultSortOrder":"a","tooltip":"Full cost, including tuition & fees, room & board, and books & supplies. Actual net cost may vary based on a student’s academic success and family income. Source: IPEDS"},{"text":"Total 4 Year Cost","data":"CostOff","dataType":"currencyString","sortType":"float","negatedFilters":["onCampus"],"defaultSortOrder":"a","tooltip":"Full cost, including tuition & fees, room & board, and books & supplies. Actual net cost may vary based on a student’s academic success and family income. Source: IPEDS"},{"text":"Graduation Rate","data":"GradRate","dataType":"percentString","sortType":"float","defaultSortOrder":"d","mobileText":"Grad Rate","tooltip":"% of full-time, first-time degree seeking undergrad students who began their studies at the given school and graduate within 6 years. Source: IPEDS"},{"text":"Typical Years to Graduate","data":"GradTime","defaultSortOrder":"a","mobileText":"Time to Graduate","tooltip":"# of years it takes for at least 65 percent of graduates from a given school to receive their diplomas. ...
#         var collegeRoiData = [{"Name":"Adams State College","CostOn":"$80,400","CostOff":"$83,400","RoiOn":"$93,000","RoiOff":"$90,000","RoiAidOn":"$126,000","RoiAidOff":"$123,000","AnnRoiOn":"3.9%","AnnRoiOff":"3.7%","AnnRoiAidOn":"6.7%","AnnRoiAidOff":"6.3%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(In-State)"},{"Name":"Adams State College","CostOn":"$123,000","CostOff":"$126,000","RoiOn":"$50,100","RoiOff":"$47,100","RoiAidOn":"$82,700","RoiAidOff":"$79,700","AnnRoiOn":"1.7%","AnnRoiOff":"1.6%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"3.1%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Adelphi University","CostOn":"$194,000","CostOff":"$194,000","RoiOn":"$292,000","RoiOff":"$293,000","RoiAidOn":"$362,000","RoiAidOff":"$362,000","AnnRoiOn":"4.7%","AnnRoiOff":"4.7%","AnnRoiAidOn":"7.1%","AnnRoiAidOff":"7.1%","GradRate":"64%","GradTime":"4 Years","Grant":"93%","LoanAmt":"$33,300","Url":"Adelphi_University/Salary","Img":"Adelphi University_50px.png","Tuition":"(Private)"},{"Name":"Adrian College","CostOn":"$177,000","CostOff":"$164,000","RoiOn":"($56,200)","RoiOff":"($42,700)","RoiAidOn":"$29,300","RoiAidOff":"$42,700","AnnRoiOn":"-1.9%","AnnRoiOff":"-1.5%","AnnRoiAidOn":"1.4%","AnnRoiAidOff":"2.2%","GradRate":"57%","GradTime":"4 Years","Grant":"98%","LoanAmt":"$30,800","Url":"Adrian_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Agnes Scott College","CostOn":"$192,000","CostOff":"$159,000","RoiOn":"($23,100)","RoiOff":"$9,700","RoiAidOn":"$81,000","RoiAidOff":"$114,000","AnnRoiOn":"-0.6%","AnnRoiOff":"0.3%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"5.7%","GradRate":"73%","GradTime":"4 Years","Grant":"100%","LoanAmt":"$28,300","Url":"Agnes_Scott_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$111,000","CostOff":"$114,000","RoiOn":"$203,000","RoiOff":"$201,000","RoiAidOn":"$234,000","RoiAidOff":"$231,000","AnnRoiOn":"5.3%","AnnRoiOff":"5.2%","AnnRoiAidOn":"7.0%","AnnRoiAidOff":"6.8%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$72,400","CostOff":"$83,500","RoiOn":"$34,500","RoiOff":"$23,400","RoiAidOn":"$71,000","RoiAidOff":"$59,800","AnnRoiOn":"2.0%","AnnRoiOff":"1.2%","AnnRoiAidOn":"5.6%","AnnRoiAidOff":"4.2%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(In-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$99,500","CostOff":"$111,000","RoiOn":"$7,400","RoiOff":"($3,800)","RoiAidOn":"$43,800","RoiAidOff":"$32,700","AnnRoiOn":"0.4%","AnnRoiOff":"-0.2%","AnnRoiAidOn":"2.7%","AnnRoiAidOff":"1.8%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(Out-of-State)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$84,700","CostOff":"$87,600","RoiOn":"$230,000","RoiOff":"$227,000","RoiAidOn":"$260,000","RoiAidOff":"$257,000","AnnRoiOn":"6.8%","AnnRoiOff":"6.6%","AnnRoiAidOn":"9.2%","AnnRoiAidOff":"8.9%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(In-State)"},{"Name":"Albany State University","CostOn":"$122,000","CostOff":"$129,000","RoiOn":"($38,900)","RoiOff":"($46,400)","RoiAidOn":"($14,000)","RoiAidOff":"($21,500)","AnnRoiOn":"-1.9%","AnnRoiOff":"-2.2%","AnnRoiAidOn":"-0.8%","AnnRoiAidOff":"-1.1%","GradRate":"40%","Grad ...
#
#     </script>

# %% [markdown]
# We realize that the ROI data is in a JSON-File. We develop a small regular expressions that delivers the JSON file.

# %%
roi_as_json = re.search(r'collegeRoiData\s*=\s*(\[.*?\])', roi_data.string, flags=re.DOTALL | re.MULTILINE)

# %% [markdown]
# Let's have a look at the results.

# %%
print(json_text.group(1))
# Out:
# [{"Name":"Adams State College","CostOn":"$80,400","CostOff":"$83,400","RoiOn":"$93,000","RoiOff":"$90,000","RoiAidOn":"$126,000","RoiAidOff":"$123,000","AnnRoiOn":"3.9%","AnnRoiOff":"3.7%","AnnRoiAidOn":"6.7%","AnnRoiAidOff":"6.3%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(In-State)"},{"Name":"Adams State College","CostOn":"$123,000","CostOff":"$126,000","RoiOn":"$50,100","RoiOff":"$47,100","RoiAidOn":"$82,700","RoiAidOff":"$79,700","AnnRoiOn":"1.7%","AnnRoiOff":"1.6%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"3.1%","GradRate":"21%","GradTime":"5 Years","Grant":"92%","LoanAmt":"$25,500","Url":"Adams_State_College/Salary","Img":"Adams State College_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Adelphi University","CostOn":"$194,000","CostOff":"$194,000","RoiOn":"$292,000","RoiOff":"$293,000","RoiAidOn":"$362,000","RoiAidOff":"$362,000","AnnRoiOn":"4.7%","AnnRoiOff":"4.7%","AnnRoiAidOn":"7.1%","AnnRoiAidOff":"7.1%","GradRate":"64%","GradTime":"4 Years","Grant":"93%","LoanAmt":"$33,300","Url":"Adelphi_University/Salary","Img":"Adelphi University_50px.png","Tuition":"(Private)"},{"Name":"Adrian College","CostOn":"$177,000","CostOff":"$164,000","RoiOn":"($56,200)","RoiOff":"($42,700)","RoiAidOn":"$29,300","RoiAidOff":"$42,700","AnnRoiOn":"-1.9%","AnnRoiOff":"-1.5%","AnnRoiAidOn":"1.4%","AnnRoiAidOff":"2.2%","GradRate":"57%","GradTime":"4 Years","Grant":"98%","LoanAmt":"$30,800","Url":"Adrian_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Agnes Scott College","CostOn":"$192,000","CostOff":"$159,000","RoiOn":"($23,100)","RoiOff":"$9,700","RoiAidOn":"$81,000","RoiAidOff":"$114,000","AnnRoiOn":"-0.6%","AnnRoiOff":"0.3%","AnnRoiAidOn":"3.3%","AnnRoiAidOff":"5.7%","GradRate":"73%","GradTime":"4 Years","Grant":"100%","LoanAmt":"$28,300","Url":"Agnes_Scott_College/Salary","Img":"no_logo.png","Tuition":"(Private)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$111,000","CostOff":"$114,000","RoiOn":"$203,000","RoiOff":"$201,000","RoiAidOn":"$234,000","RoiAidOff":"$231,000","AnnRoiOn":"5.3%","AnnRoiOff":"5.2%","AnnRoiAidOn":"7.0%","AnnRoiAidOff":"6.8%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(Out-of-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$72,400","CostOff":"$83,500","RoiOn":"$34,500","RoiOff":"$23,400","RoiAidOn":"$71,000","RoiAidOff":"$59,800","AnnRoiOn":"2.0%","AnnRoiOff":"1.2%","AnnRoiAidOn":"5.6%","AnnRoiAidOff":"4.2%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(In-State)"},{"Name":"Alabama State University (ASU)","CostOn":"$99,500","CostOff":"$111,000","RoiOn":"$7,400","RoiOff":"($3,800)","RoiAidOn":"$43,800","RoiAidOff":"$32,700","AnnRoiOn":"0.4%","AnnRoiOff":"-0.2%","AnnRoiAidOn":"2.7%","AnnRoiAidOff":"1.8%","GradRate":"26%","GradTime":"5 Years","Grant":"83%","LoanAmt":"$27,500","Url":"Alabama_State_University_(ASU)/Salary","Img":"Alabama State University (ASU)_50px.png","Tuition":"(Out-of-State)"},{"Name":"Alabama A&M University (AAMU)","CostOn":"$84,700","CostOff":"$87,600","RoiOn":"$230,000","RoiOff":"$227,000","RoiAidOn":"$260,000","RoiAidOff":"$257,000","AnnRoiOn":"6.8%","AnnRoiOff":"6.6%","AnnRoiAidOn":"9.2%","AnnRoiAidOff":"8.9%","GradRate":"35%","GradTime":"5 Years","Grant":"89%","LoanAmt":"$29,700","Url":"Alabama_A%26M_University_(AAMU)/Salary","Img":"Alabama A&M University (AAMU)_50px.jpg","Tuition":"(In-State)"},{"Name":"Albany State University","CostOn":"$122,000","CostOff":"$129,000","RoiOn":"($38,900)","RoiOff":"($46,400)","RoiAidOn":"($14,000)","RoiAidOff":"($21,500)","AnnRoiOn":"-1.9%","AnnRoiOff":"-2.2%","AnnRoiAidOn":"-0.8%","AnnRoiAidOff":"-1.1%","GradRate":"40%","GradTime":"5 Years","Grant":"91%" ...

# %% [markdown]
# We can now attemp to read the JSON file as a table.

# %%
data = pd.read_json(json_text.group(1))

# %%
data.head()
# Out:
#   AnnRoiAidOff AnnRoiAidOn AnnRoiOff AnnRoiOn   CostOff    CostOn GradRate  \
# 0         6.3%        6.7%      3.7%     3.9%   $83,400   $80,400      21%
# 1         3.1%        3.3%      1.6%     1.7%  $126,000  $123,000      21%
# 2         7.1%        7.1%      4.7%     4.7%  $194,000  $194,000      64%
# 3         2.2%        1.4%     -1.5%    -1.9%  $164,000  $177,000      57%
# 4         5.7%        3.3%      0.3%    -0.6%  $159,000  $192,000      73%
#
#   GradTime Grant                           Img  LoanAmt                 Name  \
# 0  5 Years   92%  Adams State College_50px.jpg  $25,500  Adams State College
# 1  5 Years   92%  Adams State College_50px.jpg  $25,500  Adams State College
# 2  4 Years   93%   Adelphi University_50px.png  $33,300   Adelphi University
# 3  4 Years   98%                   no_logo.png  $30,800       Adrian College
# 4  4 Years  100%                   no_logo.png  $28,300  Agnes Scott College
#
#   RoiAidOff  RoiAidOn     RoiOff      RoiOn         Tuition  \
# 0  $123,000  $126,000    $90,000    $93,000      (In-State)
# 1   $79,700   $82,700    $47,100    $50,100  (Out-of-State)
# 2  $362,000  $362,000   $293,000   $292,000       (Private)
# 3   $42,700   $29,300  ($42,700)  ($56,200)       (Private)
# 4  $114,000   $81,000     $9,700  ($23,100)       (Private)
#
#                           Url
# 0  Adams_State_College/Salary
# 1  Adams_State_College/Salary
# 2   Adelphi_University/Salary
# 3       Adrian_College/Salary
# 4  Agnes_Scott_College/Salary

# %% [markdown]
# **YOUR TASK:** Let's have a look at Santa Clara University.

# %%
print(data[data.Name =='Santa Clara University'])
# Out:
#      AnnRoiAidOff AnnRoiAidOn AnnRoiOff AnnRoiOn   CostOff    CostOn GradRate  \
# 1117         8.9%        8.8%      6.4%     6.4%  $241,000  $243,000      85%
#
#      GradTime Grant                              Img  LoanAmt  \
# 1117  4 Years   71%  Santa Clara University_50px.png  $29,400
#
#                         Name RoiAidOff  RoiAidOn    RoiOff     RoiOn  \
# 1117  Santa Clara University  $680,000  $679,000  $590,000  $589,000
#
#         Tuition                            Url
# 1117  (Private)  Santa_Clara_University/Salary

# %% [markdown]
# Let's save everything as a csv-file.

# %%
data.to_csv('roi.csv', sep=';')

# %% [markdown]
# ## The US News Rankings for Santa Clara University

# %% [markdown]
# Let's make a soup from the specific file.

# %%
soup = bs(open('usnews_scu.html'), 'lxml')

# %% [markdown]
# Let's have a look.

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Find everything you need to know about Santa Clara, including tuition &amp; financial aid, student life, application info, academics &amp; more." name="description"/>
# <meta content="Santa Clara, bestcolleges, directory, nationaluniversities, profile" name="keywords"/>
# <meta content="origin" name="referrer"/>
# <meta content="Best Colleges" name="site"/>
# <meta content="Directory/Regional Universities West" name="zone"/>
# <meta content="" name="robots"/>
# <link data-test-id="relCanonical" href="https://www.usnews.com/best-colleges/santa-clara-1326" rel="canonical"/>
# <title>Santa Clara University | Santa Clara University - Profile, Rankings and Data | Santa Clara | US News Best Colleges</title>
# <script type="text/javascript">
#             window.usnFirstByteTime = new Date();
#         </script>
# <script id="usn-js-gpt" src="//www.googletagservices.com/tag/js/gpt.js" type="text/javascript"></script>
# <meta content="" name="usn-content-type"/>
# <meta class="swiftype" content="{  }" data-type="enum" name="subnav_list"/>
# <link href="/static/images/favicon.ico" rel="shortcut icon"/>
# <link href="/static/css/main.css" rel="stylesheet"/>
# <meta data-school-location="Santa Clara, CA" data-school-name="Santa Clara University" data-school-xwalk-id="122931"/>
# <meta content="How Does Santa Clara Rank Among America's Best Colleges?" property="og:title"/>
# <meta content="See how Santa Clara ranks among America's best colleges." property="og:description"/>
# <meta content="https://www.usnews.com/img/college-photo_20746.jpg" property="og:image"/>
# <style>
#             #__bs_notify__ {
#                 display: none !important;
#             }
#         </style>
# <script data-partner-name="nativo"></script>
# <script type="text/javascript">
#                 var utag_data = {
#     "organization_affiliation_general": null,
#     "site_product_subsection": "regionaluniversitieswest",
#     "site_portal": "highereducation",
#     "profile_type": "college",
#     "site_product": "bestcolleges",
#     "site_vertical": "education",
#     "subcategory_general": null,
#     "page_type": "profile",
#     "tab": "Overview",
#     "rankinglist_type": null,
#     "category_general": null,
#     "content_type": "product",
#     "stitial_fact": "1. In 2014, the top three destination countries for international students, in order of popularity, were the U.S., the U.K. and China.",
#     "site_product_section": "profile",
#     "nunjucks_template": "templates/pages/education/higher-education/colleges/profile/overview.nunj"
# };
#             </script>
# <script src="/static/js/bootstrap.js"></script>
# <!-- VWO is not yet supported by this application. Please contact tech to enable it. -->
# <script>
#     (function() {
#         'use strict';
#         var isPremiumHost = location.hostname.indexOf('premium') === 0;
#         var isPremiumUser = false, i;
#         var cookies = document.cookie.split(/;\s*/);
#
#         for (i = 0; i < cookies.length; i++) {
#             if (cookies[i].indexOf('tk=') === 0) {
#                 isPremiumUser = true;
#                 break;
#             }
#         }
#
#         if (isPremiumUser && !isPremiumHost) {
#             if (location.hostname.indexOf('colleges') === 0) {
#                 location.href = location.href.replace('colleges', 'premium').replace('rankingsandreviews.', '');
#             }
#             else if (location.hostname.indexOf('www') === 0) {
#                 location.href = location.href.replace('www', 'premium');
#             }
#         }
#         else if (isPremiumHost && !isPremiumUser) {
#             location.href = location.href.replace('premium', 'www');
#         }
#     })();
# </script>
# <script type="text/javascript">
#             (function(a,b,c,d)
#             { a='https://tags.tiqcdn.com/utag/usnews/main/prod/utag.js'; b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true; a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a); }
#             )();
#         </script>
# </head>
# <body class="usnresponsive ">
# <div class="off-canvas-wrap" data-offcanvas="">
# <div class="inner-wrap">
# <!--[if lt IE 10]>
#                    <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#                 <![endif]-->
# <header class="header">
# <div>
# <nav class="tab-bar" data-js-id="global-header-d08364c0-8d6f-43d5-a4ed-ac8f43c93dbb">
# <div class="header-outer padding-left-normal">
# <section class="header-inner">
# <div class="header-brand">
# <ul class="inline-list inline-right-tight header-logo">
# <li>
# <a class="logo-square hide-for-medium-up" href="https://www.usnews.com">
# <img src="/static/img/usn-logo-small.svg"/>
# </a>
# <a class="logo show-for-medium-up" href="https://www.usnews.com">
# <img src="/static/img/usn-logo-large.svg"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="header-nav">
# <div class="header-nav-items">
# <ul class="inline-list header-title inline-right-normal">
# <li class="">
# <a class="text-white" href="//www.usnews.com/education">
# <span class="text-large text-strong">
# <span class="bar-tight-for-large-up">Higher Education</span>
# <span class="show-for-large-up">»</span>
# </span>
# </a>
# </li>
# </ul>
# <ul class="inline-list header-links inline-right-normal">
# <li class="">
# <a href="/best-colleges/rankings">
# <span>Rankings</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/best-colleges">
# <span>Colleges</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/best-graduate-schools">
# <span>Grad Schools</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/education/online-education">
# <span>Online Colleges</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/education/best-global-universities">
# <span>Global</span>
# </a>
# </li>
# <li class="">
# <a class="pad-right-flush" href="//www.usnews.com/education/best-colleges/advice">
# <span>Advice</span>
# </a>
# </li>
# </ul>
# <section class="header-search">
# <form action="/best-colleges/search" class="relative">
# <label class="input-search" for="colleges-nav-search-35297bec-4725-4262-a01c-d54ebabb55b6">
# <svg class="icon-search-box"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#search" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <input autocorrect="off" id="colleges-nav-search-35297bec-4725-4262-a01c-d54ebabb55b6" name="school-name" placeholder="Search" type="text"/>
# </label>
# <input style="position: absolute; width: 0px; height: 0px; visibility: hidden;" type="submit"/>
# </form>
# <script>
#     USN.queueTask(function() {
#         USN.dispatcher.trigger('summon:colleges:autocomplete', function(init) {
#             init('#colleges-nav-search-35297bec-4725-4262-a01c-d54ebabb55b6');
#         });
#     });
# </script>
# </section>
# </div>
# <div class="header-nav-content"></div>
# </div>
# </section>
# <section>
# <span class="js-header-search-button show-for-medium-up display-inline-block-for-medium-up">
# <span class="js-header-search-button-show">
# <svg class="icon medium white header-icon"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#search"></use></svg>
# </span>
# <span class="js-header-search-button-kill">
# <svg class="icon medium white header-icon"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#x"></use></svg>
# </span>
# </span>
# <span class="show-for-medium-up display-inline-for-medium-up" id="header-login-desktop">
# <a data-js-trigger="login-modal" href="https://secure.usnews.com/member/login">
# <svg class="icon medium white header-icon inline-left-tighter"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#login"></use></svg>
# </a>
# </span>
# <a class="right right-off-canvas-toggle">
# <svg class="icon medium white header-icon"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#hamburger"></use></svg>
# </a>
# </section>
# </div>
# </nav>
# <script>
#         USN.queueTask(function() {
#             $('.js-header-search-button').click(function() {
#                 $('.tab-bar').toggleClass('has-search-box');
#                 $('.tab-bar.has-search-box .header-search input').focus();
#             });
#         });
#     </script>
# <aside class="right-off-canvas-menu">
# <a class="right right-off-canvas-toggle">
# <svg class="icon medium white"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#x"></use></svg>
# </a>
# <ul class="off-canvas-list block-loose">
# <li>
# <label class="off-canvas-heading">
# <a class="text-white" href="//www.usnews.com/education" style="padding: 0">
# <span>Higher Education</span>
# </a>
# </label>
# </li>
# <li>
# <form action="/best-colleges/search" class="relative">
# <label class="input-search" for="colleges-nav-search-7ee69b5f-50c5-496f-9002-e87a5cbb26a8">
# <svg class="icon-search-box"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#search" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <input autocorrect="off" id="colleges-nav-search-7ee69b5f-50c5-496f-9002-e87a5cbb26a8" name="school-name" placeholder="Search" type="text"/>
# </label>
# <input style="position: absolute; width: 0px; height: 0px; visibility: hidden;" type="submit"/>
# </form>
# <script>
#     USN.queueTask(function() {
#         USN.dispatcher.trigger('summon:colleges:autocomplete', function(init) {
#             init('#colleges-nav-search-7ee69b5f-50c5-496f-9002-e87a5cbb26a8');
#         });
#     });
# </script>
# </li>
# <li class="">
# <a href="/best-colleges/rankings">
# <span class="text-shadow">Rankings</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/best-colleges">
# <span class="text-shadow">Colleges</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/best-graduate-schools">
# <span class="text-shadow">Grad Schools</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/education/online-education">
# <span class="text-shadow">Online Colleges</span>
# </a>
# </li>
# <li class="">
# <a href="//www.usnews.com/education/best-global-universities">
# <span class="text-shadow">Global</span>
# </a>
# </li>
# <li class="">
# <a class="pad-right-flush" href="//www.usnews.com/education/best-colleges/advice">
# <span class="text-shadow">Advice</span>
# </a>
# </li>
# </ul>
# <div id="header-login-mobile">
# <ul class="off-canvas-list" style="margin-top: -25px">
# <li>
# <a data-js-trigger="login-modal" href="https://secure.usnews.com/member/login">
# <span class="header-banner-login text-small">
# <svg class="icon medium steel"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#login"></use></svg>
#                                 Log in
#                             </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="block-loose">
# <ul class="off-canvas-list" id="header-login-mobile-links"></ul>
# <ul class="off-canvas-list" id="header-login-mobile-logout"></ul>
# </div>
# <ul class="off-canvas-list block-loose ">
# <li><label>More from U.S. News</label></li>
# <li class="has-submenu"><a href="https://www.usnews.com/news">News &amp; Opinion</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="https://www.usnews.com/news">News &amp; Opinion</a></li>
# <li class="">
# <a href="https://www.usnews.com/news">News</a> </li>
# <li class="">
# <a href="https://www.usnews.com/opinion">Opinion</a> </li>
# <li class="">
# <a href="https://www.usnews.com/photos">Photos</a> </li>
# <li class="">
# <a href="http://video.usnews.com/">Video</a> </li>
# <li class="">
# <a href="https://www.usnews.com/news/best-countries">Best Countries</a> </li>
# <li class="">
# <a href="https://www.usnews.com/news/best-states">Best States</a> </li>
# <li class="">
# <a href="https://www.usnews.com/news/the-report">The Report</a> </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="https://www.usnews.com/education">Education</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="https://www.usnews.com/education">Education</a></li>
# <li class="">
# <a href="https://www.usnews.com/education">Higher Education</a> <ul class="block-tight">
# <li class="text-small"><a href="https://www.usnews.com/best-colleges/rankings">Rankings</a></li>
# <li class="text-small"><a href="https://www.usnews.com/best-colleges">Colleges</a></li>
# <li class="text-small"><a href="https://www.usnews.com/best-graduate-schools">Grad Schools</a></li>
# <li class="text-small"><a href="https://www.usnews.com/education/online-education">Online Programs</a></li>
# <li class="text-small"><a href="https://www.usnews.com/education/best-global-universities">Global</a></li>
# <li class="text-small"><a href="https://www.usnews.com/education/best-colleges/advice">Advice</a></li>
# </ul>
# </li>
# <li class="">
# <a href="https://www.usnews.com/education/best-high-schools">High Schools</a> <ul class="block-tight">
# <li class="text-small"><a href="https://www.usnews.com/education/best-high-schools/rankings-overview">Rankings</a></li>
# <li class="text-small"><a href="https://www.usnews.com/education/best-high-schools/advice">Advice</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="http://health.usnews.com/">Health</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="http://health.usnews.com/">Health</a></li>
# <li class="">
# <a href="http://health.usnews.com/wellness">Wellness</a> <ul class="block-tight">
# <li class="text-small"><a href="http://health.usnews.com/best-diet">Best Diets</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/food">Food</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/fitness">Fitness</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/family">Family</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/mind">Mind</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/aging">Aging</a></li>
# <li class="text-small"><a href="http://health.usnews.com/wellness/healthy-living">Health Living</a></li>
# </ul>
# </li>
# <li class="">
# <a href="http://health.usnews.com/health-care">Healthcare</a> <ul class="block-tight">
# <li class="text-small"><a href="http://health.usnews.com/doctors">Doctors</a></li>
# <li class="text-small"><a href="http://health.usnews.com/best-hospitals">Hospitals</a></li>
# </ul>
# </li>
# <li class="">
# <a href="http://health.usnews.com/best-nursing-homes">Senior Care</a> </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="http://money.usnews.com/">Money</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="http://money.usnews.com/">Money</a></li>
# <li class="">
# <a href="http://money.usnews.com/careers">Careers</a> <ul class="block-tight">
# <li class="text-small"><a href="http://money.usnews.com/careers/best-jobs/rankings">Best Jobs</a></li>
# <li class="text-small"><a href="http://money.usnews.com/careers/advice/applying">Applying</a></li>
# <li class="text-small"><a href="http://money.usnews.com/careers/advice/interviewing">Interviewing</a></li>
# <li class="text-small"><a href="http://money.usnews.com/careers/advice/salaries-and-benefits">Salaries &amp; Benefits</a></li>
# <li class="text-small"><a href="http://money.usnews.com/careers/advice/work-culture">Work Culture</a></li>
# </ul>
# </li>
# <li class="">
# <a href="http://money.usnews.com/investing">Investing</a> <ul class="block-tight">
# <li class="text-small"><a href="http://money.usnews.com/investing/stocks/rankings">Rankings</a></li>
# <li class="text-small"><a href="http://money.usnews.com/investing/stocks">Stocks</a></li>
# <li class="text-small"><a href="http://money.usnews.com/funds/mutual-funds">Mutual Funds</a></li>
# <li class="text-small"><a href="http://money.usnews.com/funds/etfs">ETFs</a></li>
# <li class="text-small"><a href="http://money.usnews.com/financial-advisors">Financial Advisors</a></li>
# <li class="text-small"><a href="http://money.usnews.com/529s">529s</a></li>
# <li class="text-small"><a href="http://money.usnews.com/investing/advice">Advice</a></li>
# </ul>
# </li>
# <li class="">
# <a href="http://money.usnews.com">Personal Finance</a> </li>
# <li class="">
# <a href="http://realestate.usnews.com/">Real Estate</a> <ul class="block-tight">
# <li class="text-small"><a href="http://realestate.usnews.com/places">Places</a></li>
# <li class="text-small"><a href="http://realestate.usnews.com/agents/">Agents</a></li>
# <li class="text-small"><a href="https://www.usnews.com/topics/subjects/real-estate">Advice</a></li>
# </ul>
# </li>
# <li class="">
# <a href="http://money.usnews.com/money/retirement">Retirement</a> </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="http://travel.usnews.com/">Travel</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="http://travel.usnews.com/">Travel</a></li>
# <li class="">
# <ul class="block-tight">
# <li class="text-small"><a href="http://travel.usnews.com/rankings/">Vacations</a></li>
# <li class="text-small"><a href="http://travel.usnews.com/hotels/">Hotels</a></li>
# <li class="text-small"><a href="http://travel.usnews.com/cruises/">Cruises</a></li>
# <li class="text-small"><a href="http://travel.usnews.com/rankings/travel-rewards/">Rewards</a></li>
# <li class="text-small"><a href="http://travel.usnews.com/features/">Advice</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="https://cars.usnews.com/cars-trucks">Cars</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="https://cars.usnews.com/cars-trucks">Cars</a></li>
# <li class="">
# <ul class="block-tight">
# <li class="text-small"><a href="https://cars.usnews.com/cars-trucks/rankings">Rankings</a></li>
# <li class="text-small"><a href="https://cars.usnews.com/cars-trucks/browse">New</a></li>
# <li class="text-small"><a href="https://cars.usnews.com/cars-trucks/used-cars">Used</a></li>
# <li class="text-small"><a href="https://cars.usnews.com/cars-trucks/financing">Financing</a></li>
# <li class="text-small"><a href="https://cars.usnews.com/cars-trucks/best-cars-blog">Advice</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-submenu"><a href="http://bestlawfirms.usnews.com/">Law Firms</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="http://bestlawfirms.usnews.com/">Law Firms</a></li>
# <li class="">
# <ul class="block-tight">
# <li class="text-small"><a href="http://bestlawfirms.usnews.com/">Law Firms</a></li>
# <li class="text-small"><a href="http://bestlawfirms.usnews.com/practiceareas.aspx">Practice Areas</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class=""><a href="http://realestate.usnews.com/">Real Estate</a>
# <ul class="right-submenu">
# <li class="back block-tight text-small"><a href="#">BACK</a></li>
# <li><a class="text-white" href="http://realestate.usnews.com/">Real Estate</a></li>
# </ul>
# </li>
# </ul>
# <ul class="off-canvas-list block-loose">
# <li><a class="text-light-gray text-small" href="https://www.usnews.com/info/features/contact">Contact</a></li>
# <li><a class="text-light-gray text-small" href="https://www.usnews.com/info/features/employment">Employment</a></li>
# <!-- mediakit is staying HTTP for now -->
# <li><a class="text-light-gray text-small" href="http://mediakit.usnews.com/index.php">Advertising</a></li>
# <li><a class="text-light-gray text-small" href="https://www.usnews.com/info/features/terms">Privacy / Terms &amp; Conditions</a></li>
# </ul>
# <div class="flex flex-start">
# <a aria-label="facebook" class="social flex flex-middle" href="https://www.facebook.com/usnewsandworldreport" target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#facebook"></use></svg>
# </a>
# <a aria-label="twitter" class="social flex flex-middle" href="https://twitter.com/usnews" target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#twitter"></use></svg>
# </a>
# <a aria-label="google plus" class="social flex flex-middle" href="https://plus.google.com/+usnewsworldreport" target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#google-plus"></use></svg>
# </a>
# </div>
# </aside>
# <script>
#         USN.queueTask(function() {
#             $(document)
#                 .on('open.fndtn.offcanvas', '[data-offcanvas]', function() {
#                   $('body').addClass('offcanvas-open');
#                 })
#                 .on('close.fndtn.offcanvas', '[data-offcanvas]', function() {
#                   $('body').removeClass('offcanvas-open');
#                 })
#             });
#     </script>
# <div class="mega-menu-container" data-js-id="mega-menu-container-d08364c0-8d6f-43d5-a4ed-ac8f43c93dbb">
# </div>
# </div>
# <script type="text/javascript">
#         USN.taskQueue.queueTask(function() {
#             USN.EventDispatcher.instance.dispatcher.trigger('summon:colleges:compass-header');
#         });
#     </script>
# <script>
#     USN.queueTask(function() {
#         $('[data-js-id=global-header-d08364c0-8d6f-43d5-a4ed-ac8f43c93dbb] .has-mega-menu').megaMenu({
#             shouldToggleMenu: $('html').hasClass('touch'),
#             menuContainer: '[data-js-id=mega-menu-container-d08364c0-8d6f-43d5-a4ed-ac8f43c93dbb]'
#         });
#     });
# </script>
# </header>
# <div class="content-wrapper">
# <div class="leaderboard-a-container">
# <div class="ad ad-leaderboard ad-leaderboard-a show-for-large-up" data-ad-type="lb_" data-dimensions="728x90,950x30,954x90,938x90,970x66,970x250,970x90" data-targeting='{"pos":"top"}' id="leaderboardA">
# </div>
# </div>
# <script>
#                         USN.latencyUtil.log('Pre-Fold');
#                     </script>
# <script src="/static/js/prefold.js"></script>
# <div class="hero has-floating-widget block-tightest has-photo-cover">
# <div class="hero-bg-image-container">
# <div class="hero-bg-image" style="background-image: url(https://www.usnews.com/img/college-photo_20746.jpg)"></div>
# </div>
# <div class="flex-row">
# <div class="hero-breadcrumbs show-for-medium-up">
# <ul aria-label="breadcrumbs" class="breadcrumbs show-for-medium-up block-flush" role="menubar">
# <li class="breadcrumbs-item in-hero" role="menuitem"><a href="https://www.usnews.com/higher-education">Higher Education</a></li>
# <li class="breadcrumbs-item in-hero" role="menuitem"><a href="https://www.usnews.com/best-colleges">Colleges</a></li>
# <li class="breadcrumbs-item in-hero">Santa Clara University</li>
# </ul>
# </div>
# </div>
# <div class="flex-row relative">
# <div class="flex-small-12 flex-large-8">
# <div class="flex-media hero-content-container ">
# <div class="flex-media-figure left-for-medium-up show-for-medium-up">
# <img src="/static/img/best-colleges-badge.svg" style="margin-top: 2px; height: 90px; width: 90px; margin-left: -10px; margin-right: 24px;"/>
# </div>
# <div class="flex-media-content">
# <h1 class="hero-heading flex-media-heading block-tight hero-heading text-tighter block-tight flex-media-heading ">
#         Santa Clara University    </h1>
# <div class="hero-content-main">
# <div class="flex-row large-between large-bottom flex-full-width">
# <div class="flex-small-12 hero-meta hero-ranking-data">
# <p class="block-normal hide-for-small-only text-small hero-ranking-data-contact">
#                 500 El Camino Real,
#
#             Santa Clara, CA 95053
#
#                 <span class="text-muted" style="margin: 0 5px;">|</span> (408) 554-4000
#
#         </p>
# <div class="block-normal block-flush-for-medium-up display-inline-block hero-ranking-data-rank">
# <strong>
#                     #2
#
#
#                     <span style="margin-left:0;">in</span>
# </strong>
# <a href="https://www.usnews.com/best-colleges/rankings/regional-universities-west">Regional Universities West</a>
# <span class="hide-for-small-only"> | <strong>Overall Score <span data-test-id="college_readiness_index" style="margin: 0;">95</span>/100.0</strong></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hero-social">
# <div class="flex flex-start">
# <a aria-label="facebook" class="social flex flex-middle" href="    https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326%3Fsrc=usn_fb
# " target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#facebook"></use></svg>
# </a>
# <a aria-label="twitter" class="social flex flex-middle" href="    https://twitter.com/share?url=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326%3Fsrc=usn_tw&amp;amp;text=How%20Does%20Santa%20Clara%20Rank%20Among%20America%27s%20Best%20Colleges%3F
# " target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#twitter"></use></svg>
# </a>
# <a aria-label="reddit" class="social flex flex-middle" href="    https://www.reddit.com/submit?url=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326%3Fsrc=usn_rd
# " target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#reddit"></use></svg>
# </a>
# <a aria-label="email" class="social flex flex-middle" onclick="    window.location='mailto:?subject=How%20Does%20Santa%20Clara%20Rank%20Among%20America%27s%20Best%20Colleges%3F%20%7C%20US%20News&amp;body=Find%20everything%20you%20need%20to%20know%20about%20Santa%20Clara%2C%20including%20tuition%20%26%20financial%20aid%2C%20student%20life%2C%20application%20info%2C%20academics%20%26%20more.%20%20https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326'; return false;
# " target="_blank">
# <svg class="icon medium "><use xlink:href="/static/sprites/svg/sprite.symbol.svg#mail"></use></svg>
# </a>
# <a aria-controls="social-more" aria-expanded="false" aria-label="more" class="social flex flex-middle last" data-dropdown="social-morea0eda4fe-94ad-4e63-a168-bbfd62df22e4" href="#">
# <span>MORE</span>
# </a>
# <ul aria-hidden="true" class="social-more f-dropdown" data-dropdown-content="" id="social-morea0eda4fe-94ad-4e63-a168-bbfd62df22e4" tabindex="-1">
# <li>
# <a class="display-block" href="    https://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326&amp;src=usn_li&amp;title=How%20Does%20Santa%20Clara%20Rank%20Among%20America%27s%20Best%20Colleges%3F&amp;summary=Find%20everything%20you%20need%20to%20know%20about%20Santa%20Clara%2C%20including%20tuition%20%26%20financial%20aid%2C%20student%20life%2C%20application%20info%2C%20academics%20%26%20more.&amp;source=U.%20S.%20News
# " target="_blank">
# <svg class="icon medium color-linkedin"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#linkedin"></use></svg>
#
#                         LinkedIn
#                     </a>
# </li>
# <li>
# <a class="display-block" href="    https://www.stumbleupon.com/badge/?url=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326%3Fsrc=usn_su
# " target="_blank">
# <svg class="icon medium color-stumbleupon"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#stumbleupon"></use></svg>
#
#                         StumbleUpon
#                     </a>
# </li>
# <li>
# <a class="display-block" href="    https://plus.google.com/share?url=https%3A%2F%2Fwww.usnews.com%2Fbest-colleges%2Fsanta-clara-1326%3Fsrc=usn_gp
# " target="_blank">
# <svg class="icon medium color-google-plus"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#google-plus"></use></svg>
#
#                         Google +
#                     </a>
# </li>
# <li>
# <a class="dropdown-close hide-for-medium-up" href="#">Cancel</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="js-sleeper-agent" data-agent-id="photo-stream" data-agent-on-move-event="photoStreamMove" data-agent-trigger="BREAKPOINT-LARGE"></div>
# </div>
# </div>
# </div>
# <div class="block-loose sub-nav-container" data-scroll-to-fixed="unlimited">
# <div class="row">
# <div class=" large-8 columns ">
# <div class="sub-nav rail-sticky-offset-target" id="sub-nav-ce5bd59b-fbda-481f-bae1-2c7d99ddb76d">
# <ul class="sub-nav-links">
# <li class="active">
# <a href="/best-colleges/santa-clara-1326/index">
# <span>Overview</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/overall-rankings">
# <span>Rankings</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/applying">
# <span>Applying</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/paying">
# <span>Cost &amp; Aid</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/academics">
# <span>Academics</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/student-life">
# <span>Student Life</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/campus-info">
# <span>Services</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/campus-safety">
# <span>Safety</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/rankings">
# <span>Indicators</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/photos">
# <span>Photos</span>
# </a>
# </li>
# <li class="">
# <a href="/best-colleges/santa-clara-1326/map">
# <span>Map</span>
# </a>
# </li>
# <li aria-controls="more-ce5bd59b-fbda-481f-bae1-2c7d99ddb76d" aria-expanded="false" class="more is-hidden" data-dropdown="more-dropdown-ce5bd59b-fbda-481f-bae1-2c7d99ddb76d">
# <a href="#">
# <span>More ▾</span>
# </a>
# </li>
# </ul>
# <div class="sub-nav-right">
# </div>
# </div>
# <div aria-hidden="true" class="sub-nav-dropdown f-dropdown tiny" data-dropdown-content="" id="more-dropdown-ce5bd59b-fbda-481f-bae1-2c7d99ddb76d">
# <ul>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script>
#     USN.queueTask(function() {
#         $('#sub-nav-ce5bd59b-fbda-481f-bae1-2c7d99ddb76d>.sub-nav-links').responsiveNav();
#         USN.EventDispatcher.instance.dispatcher.trigger('summon:ui:nav-waypoints', function(navWps) {
#             new navWps();
#         });
#
#         //Fixes Foundation dropdown going offscreen
#         $('[data-dropdown-content]').on('opened.fndtn.dropdown', function(e) {
#             //The bug only occurs at the medium breakpoint
#             var isMediumBp = (640 < $(window).outerWidth() && $(window).outerWidth() < 1024);
#             if (isMediumBp) {
#                 $(this).addClass('sub-nav-dropdown--right-aligned')
#             }
#         });
#
#         $('[data-dropdown-content]').on('closed.fndtn.dropdown', function(e) {
#             $(this).removeClass('sub-nav-dropdown--right-aligned')
#         });
#     });
# </script>
# <div class="flex-row sticky-container" id="content-main">
# <div class="flex-small-12 flex-large-8">
# <div class="clearfix">
# <h2 class="heading-larger block-normal">Overview</h2>
# <div class="block-tight hide-for-large-up js-sleeper-agent" data-agent-id="stats-widget" data-agent-trigger="BREAKPOINT-SMALL">
# <div class="hero-stats-widget" id="15fc6d1a-9557-494f-9a7e-492056558313">
# <header class="hero-stats-widget-header hide-for-small-only">
# <h3 class="hero-stats-widget-title">School Details</h3>
# </header>
# <section class="hero-stats-widget-map" style="position:relative">
# <a class="block-tight" href="/best-colleges/santa-clara-1326/map">
# <div id="145579e2-da13-4a3a-b90f-6516ccd99097" style="height: 200px; z-index: 1"></div>
# </a>
# <p class="block-flush" style="padding: 4px 12px; background: rgba(255,255,255, 0.75); border-bottom: 1px solid #ddd; border-top: 1px solid #ddd; height: 33px; position:absolute; bottom:0; width:100%; z-index: 2">
# <strong class="left">Santa Clara, CA</strong>
# <a class="right text-small" href="/best-colleges/santa-clara-1326/map"><svg class="icon link"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#zoom"></use></svg> Map</a>
# </p>
# </section>
# <section class="hero-stats-widget-stats">
# <h4 class="full-width">2017 Quick Stats</h4>
# <ul>
# <li><span>Tuition &amp; Fees</span> <strong>$47,112 (2016-17)</strong></li>
# <li><span>Room and Board</span> <strong>$13,965 (2016-17)</strong></li>
# <li><span>Total Enrollment</span> <strong>8,680</strong></li>
# <li><span>Application Deadline</span> <strong>Jan. 7</strong></li>
# </ul>
# </section>
# <section class="hero-stats-widget-links">
# <h4 class="full-width">More from this School</h4>
# <ul class="no-bullet inline-list full-width">
# <li><a href="https://www.usnews.com/best-colleges/santa-clara-university-1326">Undergraduate</a></li>
# <li><a href="https://www.usnews.com/best-graduate-schools/top-graduate-schools/santa-clara-university-122931">Graduate</a></li>
# </ul>
# </section>
# <footer class="hero-stats-widget-footer text-center hide-for-small-only">
# <p class="text-strong text-coal text-small block-tight">You're not seeing all the data we have!</p>
# <a class="button block tiny radius action shadow block-tight" href="https://www.usnews.com/usnews/store/college_compass.htm" style="width: 100%">
# <svg class="icon white"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#lock"></use></svg>
#                 Unlock With Compass
#             </a>
# </footer>
# <script type="text/javascript">
#         USN.taskQueue.queueTask(function() {
#             USN.EventDispatcher.instance.dispatcher.trigger('summon:ui:maps', function(Map) {
#                 var context      = document.getElementById('15fc6d1a-9557-494f-9a7e-492056558313');
#                 var mapContainer = document.getElementById('145579e2-da13-4a3a-b90f-6516ccd99097');
#                 var mapInstance  = new Map(mapContainer, {lat:37.3493, lon:-121.9379});
#                 mapInstance.map.attributionControl._container.parentElement.className = 'leaflet-top leaflet-right';
#             });
#         });
#     </script>
# </div>
# </div>
# <div class="js-sleeper-agent" data-agent-id="photo-stream" data-agent-on-move-event="photoStreamMove" data-agent-trigger="BREAKPOINT-SMALL">
# <div class="flex-media block-normal">
# <div class="hero-photos">
# <div class="hero-photos-listing">
# <div class="hero-photos-listing-item">
# <a href="/best-colleges/santa-clara-1326/photos">
# <img src="https://www.usnews.com/img/college-photo_1987_256x256mm.jpg" width="100%"/>
# </a>
# </div>
# <div class="hero-photos-listing-item">
# <a href="/best-colleges/santa-clara-1326/photos">
# <img src="https://www.usnews.com/img/college-photo_1988_256x256mm.jpg" width="100%"/>
# </a>
# </div>
# <div class="hero-photos-listing-item">
# <a href="/best-colleges/santa-clara-1326/photos">
# <img src="https://www.usnews.com/img/college-photo_2018_256x256mm.jpg" width="100%"/>
# </a>
# </div>
# <div class="hero-photos-listing-item">
# <a href="/best-colleges/santa-clara-1326/photos">
# <img src="https://www.usnews.com/img/college-photo_20746_256x256mm.jpg" width="100%"/>
# </a>
# </div>
# <a class="hero-photos-listing-link" href="/best-colleges/santa-clara-1326/photos">
# <span class="display-block-for-large">View All</span>
#                 11 Photos »
#             </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-loose">
# <p class="block-normal">Santa Clara University is a private institution that was founded in 1851. It has a total undergraduate enrollment of 5,385, its setting is city, and the campus size is 106 acres. It utilizes a differs by program-based academic calendar. Santa Clara University's ranking in the 2017 edition of Best Colleges is Regional Universities West, 2. Its tuition and fees are $47,112 (2016-17).</p>
# <p class="block-normal"></p><p align="left justify">Santa Clara University is located in the Silicon Valley town of Santa Clara, California, about an hour from San Francisco. The university offers arts and entertainment programs at the Center of Performing Arts and the de Saisset Museum of art and history. There are more than 100 student organizations on campus including the Santa Clara Community Action Program, a volunteer service organization, and the Santa Clara Review, a biannual literary magazine. Santa Clara offers housing in its residence halls, and students can also join a Residential Learning Community. The Santa Clara Broncos field nearly 20 Division I athletic teams and are known for their successful soccer and volleyball programs. The Ruff Riders – the official student booster club of SCU athletics – is the largest organization on campus.</p>
# <p class="block-normal"></p><p align="left justify">Santa Clara’s graduate programs include the <a href="http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-business-schools/items/01027">Leavey School of Business</a>, <a href="http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-law-schools/items/03012">School of Law</a>, <a href="http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-engineering-schools/santa-clara-university-02019">School of Engineering</a> and Jesuit School of Theology. Approximately one third of students study abroad during their time at Santa Clara. Undergraduates can study in either the College of Arts and Sciences, Leavey School of Business or School of Engineering. Santa Clara’s annual President’s Speaker Series has featured Santa Clara alumna and former U.S. Secretary of Homeland Security Janet Napolitano, primatologist and U.N. Messenger of Peace Jane Goodall, and Santa Clara alumnus and author of the best-selling novel "The Kite Runner" Khaled Hosseini.</p>
# </div>
# </div>
# <div class="block-looser text-center js-sleeper-agent hide-for-large-up" data-agent-id="rectangleA-sleeper" data-agent-on-move-event="adMoved" data-agent-trigger="BREAKPOINT-MEDIUM">
# <div class="ad ad-rectangle " data-ad-type="rect_" data-dimensions="300x250,300x600,300x900,300x1050" data-targeting='{"pos":"top"}' id="rectangleA">
# </div>
# </div>
# <div class="block-looser">
# <h3 class="heading-normal display-block block-loose">General Information</h3>
# <div class="stat-list block-tight">
# <div class="flex-row">
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#high-schools"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">Private, Coed</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     school type
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#flag"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">1851</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     year founded
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#book"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">Catholic</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     religious affiliation
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="stat-list block-tight">
# <div class="flex-row">
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#calendar"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">Differs by program</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     academic calendar
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#map-marker"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">City</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     setting
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# <ul class=" flex-small-12 flex-large stat-list-col block-flush no-bullet text-muted">
# <li class="block-loose block-flush-for-large-up">
# <div class="flex-row">
# <div class="flex-fixed bar-tight" style="padding-right: 0;">
# <svg class="icon large muted" xmlns="http://www.w3.org/2000/svg"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#money"></use></svg>
# </div>
# <div class="flex-small" style="padding-left: 0;">
# <span class="heading-small text-black text-tight block-flush display-block-for-large-up">$884.7 million +</span>
# <span class="subheader text-smaller text-muted text-uppercase display-block-for-large-up">
#                                     2015 endowment
#
#                                 </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <h3 class="heading-normal block-normal">School Mission and Unique Qualities</h3>
# <div class="text-muted block-normal">Content is provided by the school.</div>
# <p id="truncate-10663daa-800e-4eb1-8db3-2a107c7dc341">
#         Santa Clara University, a comprehensive Jesuit, Catholic university in Silicon Valley, offers its students rigorous undergraduate curricula in arts and sciences, business, and engineering, plus master's and law degrees and a doctorate in engineering. Distinguished nationally by one of the highest graduation rates among all U.S. master's universities, California's oldest operating higher-education institution demonstrates faith-inspired values of ethics and social justice. Founded in 1851 by the Society of Jesus as Santa Clara College, SCU was established on the site of Mission Santa Clara de Asis, the eighth of 21 California missions. The university draws upon more than 450 years of the Jesuit tradition to educate students and citizens prepared to contribute to a more just, humane, and sustainable world. High student satisfaction and achievement are reflected in the fact that 95 percent of freshman students advance to the sophomore year and 84 percent graduate within six years, among the highest percentages in the country. In addition, in 2016 Kiplinger's Personal Finance Magazine named Santa Clara University among the top 30th of best values among private universities nationwide, and PayScale ranked SCU in the top 10 percent of schools in Return on Investment in 2016. Santa Clara University was also listed among the top 200 best value colleges by Princeton Review. The School of Law's intellectual property program has been recognized among the top 6 in the country. Santa Clara's emphasis on a community of scholars and integrated education attracts faculty members who are as committed to their students' intellectual and moral development as they are to pursuing their own scholarship. SCU's 539 full-time faculty members include Fulbright professors, nationally recognized authors and poets, groundbreaking scientists, and highly regarded economic forecasters. The integration of Santa Clara University and the Jesuit School of Theology at Berkeley (JST) in 2009 resulted in the new Jesuit School of Theology of Santa Clara University. Located 40 miles south of San Francisco, in the heart of Silicon Valley, Santa Clara University offers abundant career opportunities and access to a variety of educational, cultural, and recreational activities. The 106-acre campus features beautiful gardens and landscaping, and contains more than 50 buildings, the newest being the Schott Admission &amp; Enrollment Services Building, which combines the offices of Admission, Financial Aid, the Bursar, and Registrar under one roof and features an interactive exhibit about the university.   At Santa Clara, the notion of sustainability informs many of the classes and campus activities. SCU received a Gold rating in the nation's second comprehensive sustainability rating system for colleges and universities and was also named by the Princeton Review as one of the top "50 Green Colleges" in the nation (19th). Santa Clara University has over 90,000 alumni who live in all 50 states and in 130 foreign countries. SCU alumni have held significant government posts, including Janet Napolitano, former Secretary of the Department of Homeland Security and current president of the University of California system, and Leon Panetta as former Secretary of Defense.
#     </p>
# <script>
#         USN.queueTask(function() {
#             $('#truncate-10663daa-800e-4eb1-8db3-2a107c7dc341').truncate({
#                 length: 200,
#                 collapse: true
#             });
#         });
#     </script>
# <div class="block-looser">
# <div class="border-bottom block-normal">
# <h2 class="heading-larger block-normal" id="2017 Rankings-section" style="padding-top:60px;margin-top:-60px">2017 Rankings</h2>
# <p>Santa Clara University is ranked #2 in Regional Universities West. Schools are ranked according to their performance across a set of widely accepted indicators of excellence.</p>
# <div class="block-normal">
# <img class="left" src="/static/img/mini-badge-color.svg" style="width: 1.5rem;"/>
# <div style="margin-left: 2rem;">
# <div>
# <strong>#2</strong>
#                             in <a href="https://www.usnews.com/best-colleges/rankings/regional-universities-west">Regional Universities West</a>
# </div>
# </div>
# </div>
# <div class="block-normal">
# <img class="left" src="/static/img/mini-badge-color.svg" style="width: 1.5rem;"/>
# <div style="margin-left: 2rem;">
# <div>
# <strong>#2</strong>
#                             in <a href="https://www.usnews.com/best-colleges/rankings/regional-universities-west/veterans">Best Colleges for Veterans</a>
# </div>
# </div>
# </div>
# <div class="block-normal">
# <img class="left" src="/static/img/mini-badge-color.svg" style="width: 1.5rem;"/>
# <div style="margin-left: 2rem;">
# <div>
# <strong>#63</strong>
# <span class="text-muted">(tie)</span>                            in <a href="https://www.usnews.com/best-colleges/rankings/business">Business Programs</a>
# </div>
# </div>
# </div>
# <div class="block-normal">
# <a class="text-strong" href="/best-colleges/santa-clara-1326/overall-rankings">See all Best Colleges rankings »</a>
# </div>
# <p class="block-normal text-small text-muted">
#                 See all <a href="/best-colleges/santa-clara-1326/rankings">scores and key indicators</a>.<br/>
#                 Read more about <a href="https://www.usnews.com/education/best-colleges/articles/rankings-methodologies">how we rank schools</a>.
#             </p>
# </div>
# <span class="text-strong">Other rankings at this school:</span>
# <a href="https://www.usnews.com/best-graduate-schools/top-graduate-schools/santa-clara-university-122931">Graduate</a> </div>
# <div class="block-looser text-center js-sleeper-agent hide-for-large-up" data-agent-id="rectangleB-sleeper" data-agent-on-move-event="adMoved" data-agent-trigger="BREAKPOINT-MEDIUM">
# <div class="ad ad-rectangle" data-ad-type="rect_" data-dimensions="300x250,300x600,300x280,300x300" data-targeting='{"pos":"bot"}' id="rectangleB">
# </div>
# <script>
#   USN.queueTask(function() {
# ...
#                     Studying in the United States
#                 </a>
# </h3>
# </div>
# </div>
# </div>
# <div class=" ">
# <a class="button bordered radius full-width block-flush" href="/education/best-colleges/advice">All College Advice</a>
# </div>
# </div>
# <div class="border-bottom pad-loose block-loose ">
# <div>
# <h3 class="heading-large">Compare Colleges</h3>
# <div id="container-7d7b49bc-3fe0-402f-8767-d886bbfb5acc">
# <div class="border text-center" style="padding-top: 5rem; padding-bottom: 4rem;">
# <img alt="" class="block-normal" src="/static/img/busy-spinner.svg" width="25%"/>
# <div class="text-muted text-emphasized">Loading...</div>
# </div>
# </div>
# </div>
# <script>
#     USN.queueTask(function() {
#         USN.Compare.fetchComparisonSetModule().then(function(init) {
#             init('container-7d7b49bc-3fe0-402f-8767-d886bbfb5acc');
#         });
#     });
# </script>
# </div>
# <div class="rail-sticky" data-limit-container=".sticky-container" data-scroll-to-fixed="limited" data-top-offset-element=".rail-sticky-offset-target" data-top-padding="15" data-z-index="2">
# <div class=" show-for-large-up">
# <div class="js-sleeper-agent" data-agent-id="rectangleB-sleeper" data-agent-on-move-event="adMoved" data-agent-trigger="BREAKPOINT-LARGE">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer id="footer-container">
# <aside>
# <div class="row">
# <div class="small-12 column">
# <div class="ad ad-leaderboard ad-leaderboard-b show-for-large-up border-bottom padding-bottom-tight border-top padding-top-tight block-loosest" data-ad-type="lb_" data-dimensions="728x90" data-is-full-width="true" data-targeting='{"pos":"bot"}' id="leaderboardB">
# </div>
# </div>
# </div>
# </aside>
# <aside>
# </aside>
# <footer>
# <div class="fat-footer">
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-small-12 ">
# <h3 class="heading-large heading-larger-for-medium-up block-normal block-tight-for-medium-up">Find the Best College</h3>
# </div>
# </div>
# <div class="flex-row block-normal">
# <div class="flex-small-12 hide-for-medium-up">
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-full-width show-for-medium-up">
# <div class="block-normal" style="margin: 0 auto;">
# <a href="/best-colleges/rankings">
# <img alt="" height="130" src="/static/img/circle-badge-icon.svg" width="130"/>
# </a>
# </div>
# </div>
# <div class="flex-fixed large-last hide-for-medium-up">
# <div class="block-normal">
# <a href="/best-colleges/rankings">
# <img alt="" class="hide-for-medium-up" src="/static/img/circle-badge-icon.svg" style="width: 60px;"/>
# </a>
# </div>
# </div>
# <div class="flex-small medium-text-center">
# <h4 class="heading-normal heading-large-for-medium-up block-tighter block-tight-for-medium-up">
# <a class="text-black" href="/best-colleges/rankings">Best Colleges Rankings</a>
# </h4>
# <p class="text-muted text-small text-normal-for-medium-up block-normal block-loose-for-medium-up">See the best National Universities, Liberal Arts Colleges and more.</p>
# <a class="show-for-medium-up text-strong text-large" href="/best-colleges/rankings">See All Rankings »</a>
# </div>
# </div>
# </div>
# <div class="flex-small-12 flex-medium-4" data-js-id="search-feature">
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-full-width show-for-medium-up">
# <div class="block-normal" style="margin: 0 auto;">
# <a href="/best-colleges/search">
# <img alt="" height="130" src="/static/img/circle-search-icon.svg" width="130"/>
# </a>
# </div>
# </div>
# <div class="flex-fixed large-last hide-for-medium-up">
# <div class="block-normal">
# <a href="/best-colleges/search">
# <img alt="" class="hide-for-medium-up" src="/static/img/circle-search-icon.svg" style="width: 60px;"/>
# </a>
# </div>
# </div>
# <div class="flex-small medium-text-center">
# <h4 class="heading-normal heading-large-for-medium-up block-tighter block-tight-for-medium-up">
# <a class="text-black" href="/best-colleges/search">Search for a College</a>
# </h4>
# <p class="text-muted text-small text-normal-for-medium-up block-normal block-loose-for-medium-up">Already know what you are looking for? This is a good place to start.</p>
# <a class="show-for-medium-up text-strong text-large" href="/best-colleges/search">Go to Advanced Search »</a>
# </div>
# </div>
# </div>
# <div class="flex-small-12 flex-medium-4" data-js-id="compare-feature">
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-full-width show-for-medium-up">
# <div class="block-normal" style="margin: 0 auto;">
# <a href="/best-colleges/compare">
# <img alt="" height="130" src="/static/img/circle-compare-icon.svg" width="130"/>
# </a>
# </div>
# </div>
# <div class="flex-fixed large-last hide-for-medium-up">
# <div class="block-normal">
# <a href="/best-colleges/compare">
# <img alt="" class="hide-for-medium-up" src="/static/img/circle-compare-icon.svg" style="width: 60px;"/>
# </a>
# </div>
# </div>
# <div class="flex-small medium-text-center">
# <h4 class="heading-normal heading-large-for-medium-up block-tighter block-tight-for-medium-up">
# <a class="text-black" href="/best-colleges/compare">Compare Colleges</a>
# </h4>
# <p class="text-muted text-small text-normal-for-medium-up block-normal block-loose-for-medium-up">Select colleges that interest you and see a side-by-side comparison.</p>
# <a class="show-for-medium-up text-strong text-large" href="/best-colleges/compare">Start a comparison now »</a>
# </div>
# </div>
# </div>
# <div class="flex-small-12 flex-medium-4" data-js-id="compass-feature">
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-full-width show-for-medium-up">
# <div class="block-normal" style="margin: 0 auto;">
# <a href="https://www.usnews.com/usnews/store/college_compass.htm">
# <img alt="" height="130" src="/static/img/compass.svg" width="178"/>
# </a>
# </div>
# </div>
# <div class="flex-fixed large-last hide-for-medium-up">
# <div class="block-normal">
# <a href="https://www.usnews.com/usnews/store/college_compass.htm">
# <img alt="" class="hide-for-medium-up" src="/static/img/compass.svg" style="width: 60px;"/>
# </a>
# </div>
# </div>
# <div class="flex-small medium-text-center">
# <h4 class="heading-normal heading-large-for-medium-up block-tighter block-tight-for-medium-up">
# <a class="text-black" href="https://www.usnews.com/usnews/store/college_compass.htm">College Compass</a>
# </h4>
# <p class="text-muted text-small text-normal-for-medium-up block-normal block-loose-for-medium-up">Get access to all of the U.S. News Best Colleges rankings data.</p>
# <a class="show-for-medium-up text-strong text-large" href="https://www.usnews.com/usnews/store/college_compass.htm">Unlock with Compass »</a>
# </div>
# </div>
# </div>
# <script>
#          USN.taskQueue.queueTask(function() {
#              USN.EventDispatcher.instance.dispatcher.trigger('summon:compass:premium-promise', function(premiumPromise) {
#                  premiumPromise.then(
#                      function(isPremium) {
#                          if (isPremium) {
#                              $('[data-js-id="search-feature"]').addClass('flex-medium-6');
#                              $('[data-js-id="compare-feature"]').addClass('flex-medium-6');
#                              $('[data-js-id="compass-feature"]').hide();
#                          }
#                      }
#                  );
#              });
#          });
#         </script>
# </div>
# <div class="flex-row block-normal-for-medium-up show-for-medium-up display-flex-for-medium-up">
# <div class="flex-small-12">
# <hr/>
# </div>
# </div>
# <div class="flex-row block-normal border-bottom-for-small-only">
# <div class="flex-small-12">
# <h3 class="heading-large heading-larger-for-medium-up block-normal block-tight-for-medium-up">Higher Education Rankings</h3>
# </div>
# </div>
# <div class="flex-row block-tight show-for-medium-up display-flex-for-medium-up">
# <div class="flex-medium-3">
# <a href="/best-colleges">
# <img class="block-normal" src="/static/img/best-colleges-badge.svg"/>
# </a>
# </div>
# <div class="flex-medium-3">
# <h4 class="heading-normal">Best Colleges</h4>
# <a class="display-block block-tight" href="/best-colleges/rankings/national-universities">National Universities</a>
# <a class="display-block block-tight" href="/best-colleges/rankings/national-liberal-arts-colleges">Liberal Arts Colleges</a>
# <a class="display-block block-tight" href="/best-colleges/rankings/regional-universities">Regional Universities</a>
# <a class="display-block block-tight" href="/best-colleges/rankings/regional-colleges">Regional Colleges</a>
# <a class="display-block block-tight" href="/best-colleges/rankings/business">Business Programs</a>
# <a class="display-block block-tight" href="/best-colleges/rankings/engineering">Engineering Programs</a>
# </div>
# <div class="flex-medium-3">
# <h4 class="heading-normal">Graduate Schools</h4>
# <a class="display-block block-tight" href="/best-graduate-schools/top-business-schools">Business</a>
# <a class="display-block block-tight" href="/best-graduate-schools/top-education-schools">Education</a>
# <a class="display-block block-tight" href="/best-graduate-schools/top-engineering-schools">Engineering</a>
# <a class="display-block block-tight" href="/best-graduate-schools/top-law-schools">Law</a>
# <a class="display-block block-tight" href="/best-graduate-schools/top-medical-schools">Medicine</a>
# <a class="display-block block-tight" href="/best-graduate-schools/top-nursing-schools">Nursing</a>
# </div>
# <div class="flex-medium-3">
# <h5 class="heading-small">Online Programs</h5>
# <a class="display-block block-normal text-strong" href="/education/online-education">All Online rankings »</a>
# <h5 class="heading-small">Global Universities</h5>
# <a class="display-block block-normal text-strong" href="/education/best-global-universities">Rankings by region »</a>
# </div>
# </div>
# <div class="flex-row text-strong show-for-medium-up display-flex-for-medium-up">
# <div class="flex-medium-3 text-center">
# <a href="/education/best-colleges/articles/rankings-methodologies">
# <svg class="icon link"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#methodology"></use></svg> How We Rank Schools
#             </a>
# </div>
# <div class="flex-medium-3">
# <a href="/best-colleges/rankings">All Best Colleges »</a>
# </div>
# <div class="flex-medium-3">
# <a href="/best-graduate-schools">All Graduate »</a>
# </div>
# </div>
# <div class="flex-row block-normal border-bottom hide-for-medium-up">
# <div class="flex-small-12">
# <a class="display-block block-normal text-larger" href="/best-colleges/rankings">Best Colleges</a>
# </div>
# </div>
# <div class="flex-row block-normal border-bottom hide-for-medium-up">
# <div class="flex-small-12">
# <a class="display-block block-normal text-larger" href="/best-graduate-schools">Graduate Schools</a>
# </div>
# </div>
# <div class="flex-row block-normal border-bottom hide-for-medium-up">
# <div class="flex-small-12">
# <a class="display-block block-normal text-larger" href="/education/online-education">Online Programs</a>
# </div>
# </div>
# <div class="flex-row block-normal hide-for-medium-up">
# <div class="flex-small-12">
# <a class="display-block block-normal text-larger" href="/education/best-global-universities">Global Universities</a>
# </div>
# </div>
# <div class="flex-row hide-for-medium-up block-flush">
# <div class="flex-small-12">
# <a class="button block small bordered block-flush full" href="/best-colleges/rankings"><svg class="icon link"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#full-list"></use></svg>See all ranking lists</a>
# </div>
# </div>
# </div>
# <div aria-hidden="true" class="reveal-modal usn-modal usn-bc-modal" data-js-id="compass-ad-modal" data-options="multiple_opened:false;" data-reveal="" role="dialog"></div>
# <script>
#     USN.taskQueue.queueTask(function() {
#         USN.EventDispatcher.instance.dispatcher.trigger('summon:colleges:compass-header', function(loginPromise) {
#             loginPromise.then(
#                 function(data) {
#                     if (!data) {
#                         USN.EventDispatcher.instance.dispatcher.trigger('summon:colleges:modals:compass-ad');
#                     }
#                 }
#             );
#         });
#     });
# </script>
# <div aria-hidden="true" class="reveal-modal usn-modal" data-js-id="search-modal" data-options="multiple_opened:false;" data-reveal="" role="dialog">
# </div>
# <div aria-hidden="true" class="reveal-modal usn-modal usn-bc-modal" data-js-id="newsletter-modal" data-options="close_on_background_click:false;multiple_opened:false;" data-reveal="" role="dialog"></div>
# </footer>
# <footer>
# <div class="footer-bar">
# <div class="row">
# <div class="small-12 column">
# <nav>
# <a class="left show-for-large-up" href="https://www.usnews.com"><img data-interchange="[/static/img/usn-logo-large.svg, (large)]" height="52" width="226"/></a>
# <section class="footer-bar-section padding-left-normal-for-large-up">
# <ul class="inline-list block-flush padding-top-tight">
# <li><a href="https://www.usnews.com/info/features/about-usnews">About U.S. News</a></li>
# <li><a href="https://www.usnews.com/info/features/contact">Contact</a></li>
# <li class="show-for-medium-up"><a href="https://www.usnews.com/info/blogs/press-room">Press</a></li>
# <!-- mediakit is staying on HTTP for now -->
# <li class="show-for-medium-up"><a href="http://mediakit.usnews.com/index.php">Advertise</a></li>
# <li class="show-for-medium-up"><a href="https://www.usnews.com/info/features/employment">Jobs</a></li>
# </ul>
# </section>
# <section class="footer-bar-section padding-left-normal-for-large-up">
# <ul class="inline-list text-smaller block-flush">
# <li>Copyright 2017 © U.S. News &amp; World Report L.P.</li>
# <li><a href="https://www.usnews.com/info/features/terms">Terms and Conditions</a></li>
# <li><a href="https://www.usnews.com/info/features/terms#privacy">Privacy Policy</a></li>
# </ul>
# </section>
# </nav>
# </div>
# </div>
# </div>
# </footer>
# </footer>
# </div>
# <a class="exit-off-canvas"></a>
# </div>
# </div>
# <div class="adhesion-wrapper small-center show-for-small-only">
# <div class="ad ad-adhesion" data-ad-type="adh" data-dimensions="320x50" data-targeting='{"pos":"adh"}' id="adh">
# </div>
# <div class="adhesion-close" id="adhesion-close"></div>
# </div>
# <div class="adhesion-spacer show-for-small-only"></div>
# <script type="text/javascript">
#     (function() {
#         var $closeButton = $('#adhesion-close');
#         $closeButton.on('click', function() {
#             $('.adhesion-spacer').detach();
#             $('.adhesion-wrapper').detach();
#         });
#     })();
# </script>
# <!-- ############ FOR STYLEGUIDE MOCKS ONLY ############ -->
# <div aria-hidden="true" aria-labelledby="modalTitle" class="reveal-modal sg-modal is-debug-immune" data-reveal="" id="sg-design-modal" role="dialog" style="">
# <h3>Design Mocks</h3>
# <h5 class="text-alert"><em>No mocks found. Please add mock names and url to this page's yaml.</em></h5>
# <a aria-label="Close" class="close-reveal-modal">×</a>
# </div>
# <!-- ############ END FOR STYLEGUIDE MOCKS ONLY ############ -->
# <div aria-hidden="true" class="reveal-modal sg-modal js-sg-modal is-debug-immune" data-reveal="" id="sg-modal" role="dialog"></div>
# <div class="sg-settings-trigger js-sg-settings-trigger is-none is-debug-immune" id="cog">
# <svg class="icon large link"><use xlink:href="/static/sprites/svg/sprite.symbol.svg#cog"></use></svg>
# </div>
# <div class="sg-component-overlay js-component-overlay" id="component-overlay"></div>
# <div class="sg-console js-sg-console is-none is-debug-immune" id="mock-console"></div>
# <div class="sg-console-buffer js-sg-console-buffer is-none"></div>
# <div class="ad" data-outofpage="true" data-targeting='{"pos":"stitial"}' id="stitial">
# </div>
# <!-- The div for the email subscription popup -->
# <div aria-hidden="true" class="reveal-modal signup-modal" data-js-id="signup-modal" data-reveal="" role="dialog">
# </div>
# <script>
#             USN.latencyUtil.log('Ad JS');
#         </script>
# <script src="/static/js/chaching.js"></script>
# <script>
#             USN.latencyUtil.log('Ad JS');
#         </script>
# <script>
#             USN.queueTask(function() {
#
#                 USN.dispatcher.trigger('summon:util:ui-listeners');
#             });
#         </script>
# <script>
# </script>
# </body>
# </html>

# %% [markdown]
# We need to get the strong elements and the links.
# We store each ranking in a dictionary.
# We also create a dataframe to hold the various rankings.

# %%
ranks = dict()
scu_ranks = pd.DataFrame()

# %% [markdown]
# We want four elements:
#   * the rank
#   * the URL
#   * the Name of the Ranking
#   * the source

# %%
for ranking in soup.find_all('div', {"style": "margin-left: 2rem;"}):
    for r in ranking.find_all('strong', text=re.compile('#') ):
        ranks['Rank'] = r.text
    for url in ranking.find_all('a'):
        ranks['URL'] = url.get('href')
        ranks['Name'] = url.contents
        ranks['Source'] = 'US News'
    scu_ranks = scu_ranks.append(ranks, ignore_index=True)

# %% [markdown]
# Let's have a look at the results.

# %%
print(scu_ranks)
# Out:
#                            Name Rank   Source  \
# 0  [Regional Universities West]   #2  US News
# 1  [Best Colleges for Veterans]   #2  US News
# 2           [Business Programs]  #63  US News
#
#                                                  URL
# 0  https://www.usnews.com/best-colleges/rankings/...
# 1  https://www.usnews.com/best-colleges/rankings/...
# 2  https://www.usnews.com/best-colleges/rankings/...

# %% [markdown]
# ## Schools in the 'Regional Universities West Ranking'

# %% [markdown]
# We get the data on the 'Regional Universities West' Ranking.

# %% [markdown]
# We want the following elements:
#   * the rank of the school
#   * the name of the school
#   * the URL of the school
#   * the location of the school

# %% [markdown]
# Let's have a look at the results.

# %% [markdown]
# Clean the results

# %% [markdown]
# Save the results in a csv file.

# %%
ruw.to_csv('ruw.csv', sep=';')
